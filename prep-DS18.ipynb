# %%
#!pip install pandas
import pandas as pd
#!pip install numpy
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
# Attempt to read the file with a different encoding, such as 'ISO-8859-1' or 'latin1'
df = pd.read_csv(r"C:\Users\info\spotify\StateProvincesTableFromMSWWID2016.csv", encoding='ISO-8859-1')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
#  13  key                       32833 non-null  int64
#  14  loudness                  32833 non-null  float64
#  15  mode                      32833 non-null  int64
#  16  speechiness               32833 non-null  float64
#  17  acousticness              32833 non-null  float64
#  18  instrumentalness          32833 non-null  float64
#  19  liveness                  32833 non-null  float64
#  20  valence                   32833 non-null  float64
#  21  tempo                     32833 non-null  float64
#  22  duration_ms               32833 non-null  int64
# dtypes: float64(9), int64(4), object(10)
# memory usage: 5.8+ MB

# %%
df.shape
# Out:
# (32833, 23)

# %%
# Check missing values in a specific column
print(df.isnull().sum())
# Out:
# track_id                    0
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_id              0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
import pandas as pd

# Step 1: Clean the data by stripping any leading/trailing whitespaces and ensuring consistent case
df['track_id'] = df['track_id'].str.strip()  # Strip whitespaces from 'track_id'
df['playlist_genre'] = df['playlist_genre'].str.strip()  # Strip whitespaces from 'playlist_genre'

# Step 2: Define the genre priority order
genre_priority = ['edm', 'rap', 'pop', 'r&b', 'latin', 'rock']

# Step 3: Set the playlist_genre column as a categorical type with the specified order
df['playlist_genre'] = pd.Categorical(df['playlist_genre'], categories=genre_priority, ordered=True)

# Step 4: Sort the DataFrame by track_id and playlist_genre to prioritize higher genres
df_sorted = df.sort_values(by=['track_id', 'playlist_genre'], ascending=[True, True])

# %%
# Step 1: Count the number of duplicates before removal
duplicates_before = df[df['track_id'].duplicated()]
initial_duplicates_count = duplicates_before.shape[0]
print(f"Number of duplicates in 'track_id' before removal: {initial_duplicates_count}")

# Step 2: Count the number of occurrences of each 'playlist_genre'
genre_counts = df['playlist_genre'].value_counts()

# Step 3: Sort the genres by size (largest first)
sorted_genres = genre_counts.index

# Step 4: Sort the DataFrame by genre size
df['playlist_genre_size'] = df['playlist_genre'].map(genre_counts)

# Step 5: Remove duplicates based on 'track_id', keeping the genre with the largest size
df = df.sort_values(by=['track_id', 'playlist_genre_size'], ascending=[True, False]).drop_duplicates(subset='track_id', keep='first')

# Step 6: Check for duplicates after removal
duplicates_after = df[df['track_id'].duplicated()]
remaining_duplicates_count = duplicates_after.shape[0]
print(f"Number of remaining duplicates in 'track_id' after removal: {remaining_duplicates_count}")

# Step 7: Optionally, display the rows that are duplicates (if any)
if remaining_duplicates_count > 0:
    print("The following rows have duplicate 'track_id's after removal:")
    print(duplicates_after)
else:
    print("No remaining duplicates in 'track_id' after removal.")

# Clean up the temporary 'playlist_genre_size' column
df = df.drop(columns=['playlist_genre_size'])

# Step 8: Display the result for the genres count in each category
genre_counts_after = df['playlist_genre'].value_counts()
print("\nNumber of playlist_genre in each category after removal:")
print(genre_counts_after)
# Out:
# Number of duplicates in 'track_id' before removal: 4477
# Number of remaining duplicates in 'track_id' after removal: 0
# No remaining duplicates in 'track_id' after removal.
#
# Number of playlist_genre in each category after removal:
# playlist_genre
# rap      5057
# r&b      4918
# edm      4877
# latin    4633
# rock     4451
# pop      4420
# Name: count, dtype: int64

# %%
import pandas as pd

# Assuming df is your DataFrame
if not df.empty:
    # Group by 'track_id' and 'playlist_genre' and count the occurrences
    track_genre_counts = df.groupby(['track_id', 'playlist_genre']).size().reset_index(name='count_per_genre')

# %%
df.head()
# Out:
#                      track_id    track_name        track_artist  \
# 12644  0017A6SJgTbfQVU2EtsPNo      Pangarap     Barbie's Cradle
# 25675  002xjHwzEx66OWFV2IP9dk    The Others                RIKA
# 15061  004s3t0ONYlzxII9PLgU6z  I Feel Alive       Steady Rollin
# 2887   008MceT31RotUANsKuzy3L   Liquid Blue  The.madpix.project
# 1029   008rk8F6ZxspZT4bUlkIQG         Fever         YOSA & TAAR
#
#        track_popularity          track_album_id track_album_name  \
# 12644                41  1srJQ0njEQgd8w4XSqI4JQ             Trip
# 25675                15  1ficfUnZMaY1QkNp15Slzm       The Others
# 15061                28  3z04Lb9Dsilqw68SHt6jLB      Love & Loss
# 2887                 24  1Z4ANBVuhTlS6DprlP0m1q      Liquid Blue
# 1029                 38  2BuYm9UcKvI0ydXs5JKwt0            Fever
#
#       track_album_release_date                  playlist_name  \
# 12644               01/01/2001             Pinoy Classic Rock
# 25675               26/01/2018    Groovy // Funky // Neo-Soul
# 15061               21/11/2017              Hard Rock Workout
# 2887                07/08/2015               Electropop - Pop
# 1029                16/11/2018  Best of 2019 Dance Pop: Japan
#
#                   playlist_id playlist_genre  ... key  loudness  mode  \
# 12644  37i9dQZF1DWYDQ8wBxd7xt           rock  ...   2   -10.068     1
# 25675  0JmBB9HfrzDiZoPVRdv8ns            r&b  ...   5    -6.242     1
# 15061  3YouF0u7waJnolytf9JCXf           rock  ...   9    -4.739     1
# 2887   5TiiHps0hNCyQ6ijVkNZQs            pop  ...  10    -5.644     0
# 1029   37i9dQZF1DXdOtZGKonFlM            pop  ...   1    -6.300     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 12644       0.0236      0.279000          0.011700    0.0887    0.566
# 25675       0.0347      0.065100          0.000000    0.2120    0.698
# 15061       0.0442      0.011700          0.009940    0.3470    0.404
# 2887        0.0540      0.000761          0.132000    0.3220    0.852
# 1029        0.0499      0.114000          0.000697    0.0881    0.496
#
#          tempo  duration_ms
# 12644   97.091       235440
# 25675  150.863       197286
# 15061  135.225       373512
# 2887   128.041       228565
# 1029   129.884       236308
#
# [5 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# track_id                    0
# track_name                  4
# track_artist                4
# track_popularity            0
# track_album_id              0
# track_album_name            4
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
df_shape = df.shape
print(f"Shape of the DataFrame: {df_shape}")
# Out:
# Shape of the DataFrame: (28356, 23)

# %%
#df = df[df['track_album_release_date'].str.match(r'^\d{4}$')]
#df.head()

# %%
df.shape
# Out:
# (28356, 23)

# %%
df
# Out:
#                      track_id                              track_name  \
# 12644  0017A6SJgTbfQVU2EtsPNo                                Pangarap
# 25675  002xjHwzEx66OWFV2IP9dk                              The Others
# 15061  004s3t0ONYlzxII9PLgU6z                            I Feel Alive
# 2887   008MceT31RotUANsKuzy3L                             Liquid Blue
# 1029   008rk8F6ZxspZT4bUlkIQG                                   Fever
# ...                       ...                                     ...
# 22211  7zxRMhXxJMQCeDDg0rKAVo                                Some Way
# 24247  7zyLObYw4QUKQDyZOb4J0Y  I'll Do 4 U (Re-Recorded / Remastered)
# 3793   7zycSpvjDcqh6YT1FEl2kY                                Anaconda
# 26767  7zye9v6B785eFWEFYs13C2                                   Bound
# 12608  7zzZmpw8L66ZPjH1M6qmOs                                Migraine
#
#                    track_artist  track_popularity          track_album_id  \
# 12644           Barbie's Cradle                41  1srJQ0njEQgd8w4XSqI4JQ
# 25675                      RIKA                15  1ficfUnZMaY1QkNp15Slzm
# 15061             Steady Rollin                28  3z04Lb9Dsilqw68SHt6jLB
# 2887         The.madpix.project                24  1Z4ANBVuhTlS6DprlP0m1q
# 1029                YOSA & TAAR                38  2BuYm9UcKvI0ydXs5JKwt0
# ...                         ...               ...                     ...
# 22211                       NAV                72  4JR29CNW14Zc4Z5vflxkoJ
# 24247                 Father MC                36  14HYMxFhpgDIr9cci1u0kt
# 3793                Nicki Minaj                49  5qs8T6ZHSrnllnOuUk6muC
# 26767  Ponderosa Twins Plus One                40  1xdgLmTFMSyJyI5DJOOX7T
# 12608                Moonstar88                61  4t3FtECyV1gClHmpBhXSfB
#
#                              track_album_name track_album_release_date  \
# 12644                                    Trip               01/01/2001
# 25675                              The Others               26/01/2018
# 15061                             Love & Loss               21/11/2017
# 2887                              Liquid Blue               07/08/2015
# 1029                                    Fever               16/11/2018
# ...                                       ...                      ...
# 22211                                     NAV               24/02/2017
# 24247  I'll Do 4 U (Re-Recorded / Remastered)               01/10/2010
# 3793           The Pinkprint (Deluxe Edition)               15/12/2014
# 26767          2+2+1 = (Digitally Remastered)               09/07/2013
# 12608                          When I Met You               28/07/2008
#
#                                playlist_name             playlist_id  \
# 12644                     Pinoy Classic Rock  37i9dQZF1DWYDQ8wBxd7xt
# 25675            Groovy // Funky // Neo-Soul  0JmBB9HfrzDiZoPVRdv8ns
# 15061                      Hard Rock Workout  3YouF0u7waJnolytf9JCXf
# 2887                        Electropop - Pop  5TiiHps0hNCyQ6ijVkNZQs
# 1029           Best of 2019 Dance Pop: Japan  37i9dQZF1DXdOtZGKonFlM
# ...                                      ...                     ...
# 22211                  PROJECT: Contemporary  6HaCi9bqaiuSZEDfCEmwyo
# 24247  New Jack Swing/ R&B Hits: 1987 - 2002  4sji14lrB5bgcr51lPALYH
# 3793                           10er Playlist  1kEczIkZH8IgaWT2BiApxZ
# 26767                         Sexy Soul 2020  5EMARioe9z9eKOeWIAC2JW
# 12608                     Pinoy Classic Rock  37i9dQZF1DWYDQ8wBxd7xt
#
#       playlist_genre  ... key  loudness  mode  speechiness  acousticness  \
# 12644           rock  ...   2   -10.068     1       0.0236      0.279000
# 25675            r&b  ...   5    -6.242     1       0.0347      0.065100
# 15061           rock  ...   9    -4.739     1       0.0442      0.011700
# 2887             pop  ...  10    -5.644     0       0.0540      0.000761
# 1029             pop  ...   1    -6.300     1       0.0499      0.114000
# ...              ...  ...  ..       ...   ...          ...           ...
# 22211            r&b  ...   0    -6.103     1       0.3510      0.101000
# 24247            r&b  ...   1    -4.920     0       0.0633      0.143000
# 3793             pop  ...   2    -6.224     1       0.1800      0.067300
# 26767            r&b  ...   5    -6.457     0       0.0270      0.715000
# 12608           rock  ...   2    -6.000     1       0.0290      0.217000
#
#        instrumentalness  liveness  valence    tempo  duration_ms
# 12644          0.011700    0.0887    0.566   97.091       235440
# 25675          0.000000    0.2120    0.698  150.863       197286
# 15061          0.009940    0.3470    0.404  135.225       373512
# 2887           0.132000    0.3220    0.852  128.041       228565
# 1029           0.000697    0.0881    0.496  129.884       236308
# ...                 ...       ...      ...      ...          ...
# 22211          0.000000    0.0919    0.340  154.962       179773
# 24247          0.000000    0.0720    0.810  109.536       223890
# 3793           0.000006    0.2140    0.647  129.990       260240
# 26767          0.000428    0.1150    0.657  142.218       191205
# 12608          0.000003    0.1180    0.221  115.049       267960
#
# [28356 rows x 23 columns]

# %%
df.head()
# Out:
#                      track_id    track_name        track_artist  \
# 12644  0017A6SJgTbfQVU2EtsPNo      Pangarap     Barbie's Cradle
# 25675  002xjHwzEx66OWFV2IP9dk    The Others                RIKA
# 15061  004s3t0ONYlzxII9PLgU6z  I Feel Alive       Steady Rollin
# 2887   008MceT31RotUANsKuzy3L   Liquid Blue  The.madpix.project
# 1029   008rk8F6ZxspZT4bUlkIQG         Fever         YOSA & TAAR
#
#        track_popularity          track_album_id track_album_name  \
# 12644                41  1srJQ0njEQgd8w4XSqI4JQ             Trip
# 25675                15  1ficfUnZMaY1QkNp15Slzm       The Others
# 15061                28  3z04Lb9Dsilqw68SHt6jLB      Love & Loss
# 2887                 24  1Z4ANBVuhTlS6DprlP0m1q      Liquid Blue
# 1029                 38  2BuYm9UcKvI0ydXs5JKwt0            Fever
#
#       track_album_release_date                  playlist_name  \
# 12644               01/01/2001             Pinoy Classic Rock
# 25675               26/01/2018    Groovy // Funky // Neo-Soul
# 15061               21/11/2017              Hard Rock Workout
# 2887                07/08/2015               Electropop - Pop
# 1029                16/11/2018  Best of 2019 Dance Pop: Japan
#
#                   playlist_id playlist_genre  ... key  loudness  mode  \
# 12644  37i9dQZF1DWYDQ8wBxd7xt           rock  ...   2   -10.068     1
# 25675  0JmBB9HfrzDiZoPVRdv8ns            r&b  ...   5    -6.242     1
# 15061  3YouF0u7waJnolytf9JCXf           rock  ...   9    -4.739     1
# 2887   5TiiHps0hNCyQ6ijVkNZQs            pop  ...  10    -5.644     0
# 1029   37i9dQZF1DXdOtZGKonFlM            pop  ...   1    -6.300     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 12644       0.0236      0.279000          0.011700    0.0887    0.566
# 25675       0.0347      0.065100          0.000000    0.2120    0.698
# 15061       0.0442      0.011700          0.009940    0.3470    0.404
# 2887        0.0540      0.000761          0.132000    0.3220    0.852
# 1029        0.0499      0.114000          0.000697    0.0881    0.496
#
#          tempo  duration_ms
# 12644   97.091       235440
# 25675  150.863       197286
# 15061  135.225       373512
# 2887   128.041       228565
# 1029   129.884       236308
#
# [5 rows x 23 columns]

# %%
from IPython.display import display, HTML
display(HTML("<b>track_album_release_date</b>"))
# Out:
# <b>track_album_release_date</b>

# %%
len(df['track_id'].unique())
# Out:
# 28356

# %%
df.shape
# Out:
# (28356, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28356 entries, 12644 to 12608
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  28356 non-null  object
#  1   track_name                28352 non-null  object
#  2   track_artist              28352 non-null  object
#  3   track_popularity          28356 non-null  int64
#  4   track_album_id            28356 non-null  object
#  5   track_album_name          28352 non-null  object
#  6   track_album_release_date  28356 non-null  object
#  7   playlist_name             28356 non-null  object
#  8   playlist_id               28356 non-null  object
#  9   playlist_genre            28356 non-null  category
#  10  playlist_subgenre         28356 non-null  object
#  11  danceability              28356 non-null  float64
#  12  energy                    28356 non-null  float64
#  13  key                       28356 non-null  int64
#  14  loudness                  28356 non-null  float64
#  15  mode                      28356 non-null  int64
#  16  speechiness               28356 non-null  float64
#  17  acousticness              28356 non-null  float64
#  18  instrumentalness          28356 non-null  float64
#  19  liveness                  28356 non-null  float64
#  20  valence                   28356 non-null  float64
#  21  tempo                     28356 non-null  float64
#  22  duration_ms               28356 non-null  int64
# dtypes: category(1), float64(9), int64(4), object(9)
# memory usage: 5.0+ MB

# %%
# Get the number of columns in the DataFrame
num_columns = df.shape[1]

# Print the number of columns
print(f"Number of columns in the DataFrame: {num_columns}")
# Out:
# Number of columns in the DataFrame: 23

# %%
# Get unique values in the 'playlist_genre' column
unique_genres = df['playlist_genre'].unique()

# Display the unique genres
print(unique_genres)
# Out:
# ['rock', 'r&b', 'pop', 'latin', 'edm', 'rap']
# Categories (6, object): ['edm' < 'rap' < 'pop' < 'r&b' < 'latin' < 'rock']

# %%
# Group by 'playlist_genre' and count the occurrences of each genre
genre_counts = df.groupby('playlist_genre').size().reset_index(name='count')

# Display the result
print("Number of playlist_genre in each category:")
print(genre_counts)
# Out:
# Number of playlist_genre in each category:
#   playlist_genre  count
# 0            edm   4877
# 1            rap   5057
# 2            pop   4420
# 3            r&b   4918
# 4          latin   4633
# 5           rock   4451

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28356 entries, 12644 to 12608
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  28356 non-null  object
#  1   track_name                28352 non-null  object
#  2   track_artist              28352 non-null  object
#  3   track_popularity          28356 non-null  int64
#  4   track_album_id            28356 non-null  object
#  5   track_album_name          28352 non-null  object
#  6   track_album_release_date  28356 non-null  object
#  7   playlist_name             28356 non-null  object
#  8   playlist_id               28356 non-null  object
#  9   playlist_genre            28356 non-null  category
#  10  playlist_subgenre         28356 non-null  object
#  11  danceability              28356 non-null  float64
#  12  energy                    28356 non-null  float64
#  13  key                       28356 non-null  int64
#  14  loudness                  28356 non-null  float64
#  15  mode                      28356 non-null  int64
#  16  speechiness               28356 non-null  float64
#  17  acousticness              28356 non-null  float64
#  18  instrumentalness          28356 non-null  float64
#  19  liveness                  28356 non-null  float64
#  20  valence                   28356 non-null  float64
#  21  tempo                     28356 non-null  float64
#  22  duration_ms               28356 non-null  int64
# dtypes: category(1), float64(9), int64(4), object(9)
# memory usage: 5.0+ MB

# %%
print(df.columns)
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
df['track_id'] = df['track_id'].astype('string')
df['track_name'] = df['track_name'].astype('string')
df['track_artist'] = df['track_artist'].astype('string')
df['track_album_id'] = df['track_album_id'].astype('string')
df['track_album_name'] = df['track_album_name'].astype('string')
df['playlist_name'] = df['playlist_name'].astype('string')
df['playlist_id'] = df['playlist_id'].astype('string')
df['playlist_genre'] = df['playlist_genre'].astype('category')
df['playlist_subgenre'] = df['playlist_subgenre'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28356 entries, 12644 to 12608
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  28356 non-null  string
#  1   track_name                28352 non-null  string
#  2   track_artist              28352 non-null  string
#  3   track_popularity          28356 non-null  int64
#  4   track_album_id            28356 non-null  string
#  5   track_album_name          28352 non-null  string
#  6   track_album_release_date  28356 non-null  object
#  7   playlist_name             28356 non-null  string
#  8   playlist_id               28356 non-null  string
#  9   playlist_genre            28356 non-null  category
#  10  playlist_subgenre         28356 non-null  category
#  11  danceability              28356 non-null  float64
#  12  energy                    28356 non-null  float64
#  13  key                       28356 non-null  int64
#  14  loudness                  28356 non-null  float64
#  15  mode                      28356 non-null  int64
#  16  speechiness               28356 non-null  float64
#  17  acousticness              28356 non-null  float64
#  18  instrumentalness          28356 non-null  float64
#  19  liveness                  28356 non-null  float64
#  20  valence                   28356 non-null  float64
#  21  tempo                     28356 non-null  float64
#  22  duration_ms               28356 non-null  int64
# dtypes: category(2), float64(9), int64(4), object(1), string(7)
# memory usage: 4.8+ MB

# %%
#chek 10:50
import pandas as pd

# Convert the entire column to datetime64[ns], allowing for mixed formats
df['track_album_release_date'] = pd.to_datetime(df['track_album_release_date'], errors='coerce', dayfirst=True)
df.head()
# Out:
#                      track_id    track_name        track_artist  \
# 12644  0017A6SJgTbfQVU2EtsPNo      Pangarap     Barbie's Cradle
# 25675  002xjHwzEx66OWFV2IP9dk    The Others                RIKA
# 15061  004s3t0ONYlzxII9PLgU6z  I Feel Alive       Steady Rollin
# 2887   008MceT31RotUANsKuzy3L   Liquid Blue  The.madpix.project
# 1029   008rk8F6ZxspZT4bUlkIQG         Fever         YOSA & TAAR
#
#        track_popularity          track_album_id track_album_name  \
# 12644                41  1srJQ0njEQgd8w4XSqI4JQ             Trip
# 25675                15  1ficfUnZMaY1QkNp15Slzm       The Others
# 15061                28  3z04Lb9Dsilqw68SHt6jLB      Love & Loss
# 2887                 24  1Z4ANBVuhTlS6DprlP0m1q      Liquid Blue
# 1029                 38  2BuYm9UcKvI0ydXs5JKwt0            Fever
#
#       track_album_release_date                  playlist_name  \
# 12644               2001-01-01             Pinoy Classic Rock
# 25675               2018-01-26    Groovy // Funky // Neo-Soul
# 15061               2017-11-21              Hard Rock Workout
# 2887                2015-08-07               Electropop - Pop
# 1029                2018-11-16  Best of 2019 Dance Pop: Japan
#
#                   playlist_id playlist_genre  ... key  loudness  mode  \
# 12644  37i9dQZF1DWYDQ8wBxd7xt           rock  ...   2   -10.068     1
# 25675  0JmBB9HfrzDiZoPVRdv8ns            r&b  ...   5    -6.242     1
# 15061  3YouF0u7waJnolytf9JCXf           rock  ...   9    -4.739     1
# 2887   5TiiHps0hNCyQ6ijVkNZQs            pop  ...  10    -5.644     0
# 1029   37i9dQZF1DXdOtZGKonFlM            pop  ...   1    -6.300     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 12644       0.0236      0.279000          0.011700    0.0887    0.566
# 25675       0.0347      0.065100          0.000000    0.2120    0.698
# 15061       0.0442      0.011700          0.009940    0.3470    0.404
# 2887        0.0540      0.000761          0.132000    0.3220    0.852
# 1029        0.0499      0.114000          0.000697    0.0881    0.496
#
#          tempo  duration_ms
# 12644   97.091       235440
# 25675  150.863       197286
# 15061  135.225       373512
# 2887   128.041       228565
# 1029   129.884       236308
#
# [5 rows x 23 columns]

# %%
# Step 1: Ensure the 'track_album_release_date' is in datetime format
df['track_album_release_date'] = pd.to_datetime(df['track_album_release_date'], errors='coerce', dayfirst=True)

# Step 2: Create the 'track_album_release_year' and 'track_album_release_month' columns
df['track_album_release_year'] = df['track_album_release_date'].dt.year
df['track_album_release_month'] = df['track_album_release_date'].dt.month

# Step 3: Remove the original 'track_album_release_date' column
df = df.drop(columns=['track_album_release_date'])
df.head()
# Out:
#                      track_id    track_name        track_artist  \
# 12644  0017A6SJgTbfQVU2EtsPNo      Pangarap     Barbie's Cradle
# 25675  002xjHwzEx66OWFV2IP9dk    The Others                RIKA
# 15061  004s3t0ONYlzxII9PLgU6z  I Feel Alive       Steady Rollin
# 2887   008MceT31RotUANsKuzy3L   Liquid Blue  The.madpix.project
# 1029   008rk8F6ZxspZT4bUlkIQG         Fever         YOSA & TAAR
#
#        track_popularity          track_album_id track_album_name  \
# 12644                41  1srJQ0njEQgd8w4XSqI4JQ             Trip
# 25675                15  1ficfUnZMaY1QkNp15Slzm       The Others
# 15061                28  3z04Lb9Dsilqw68SHt6jLB      Love & Loss
# 2887                 24  1Z4ANBVuhTlS6DprlP0m1q      Liquid Blue
# 1029                 38  2BuYm9UcKvI0ydXs5JKwt0            Fever
#
#                        playlist_name             playlist_id playlist_genre  \
# 12644             Pinoy Classic Rock  37i9dQZF1DWYDQ8wBxd7xt           rock
# 25675    Groovy // Funky // Neo-Soul  0JmBB9HfrzDiZoPVRdv8ns            r&b
# 15061              Hard Rock Workout  3YouF0u7waJnolytf9JCXf           rock
# 2887                Electropop - Pop  5TiiHps0hNCyQ6ijVkNZQs            pop
# 1029   Best of 2019 Dance Pop: Japan  37i9dQZF1DXdOtZGKonFlM            pop
#
#       playlist_subgenre  ...  mode  speechiness  acousticness  \
# 12644      classic rock  ...     1       0.0236      0.279000
# 25675          neo soul  ...     1       0.0347      0.065100
# 15061         hard rock  ...     1       0.0442      0.011700
# 2887         electropop  ...     0       0.0540      0.000761
# 1029          dance pop  ...     1       0.0499      0.114000
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 12644          0.011700    0.0887    0.566   97.091       235440
# 25675          0.000000    0.2120    0.698  150.863       197286
# 15061          0.009940    0.3470    0.404  135.225       373512
# 2887           0.132000    0.3220    0.852  128.041       228565
# 1029           0.000697    0.0881    0.496  129.884       236308
#
#        track_album_release_year  track_album_release_month
# 12644                    2001.0                        1.0
# 25675                    2018.0                        1.0
# 15061                    2017.0                       11.0
# 2887                     2015.0                        8.0
# 1029                     2018.0                       11.0
#
# [5 rows x 24 columns]

# %%
df.head()
# Out:
#                      track_id    track_name        track_artist  \
# 12644  0017A6SJgTbfQVU2EtsPNo      Pangarap     Barbie's Cradle
# 25675  002xjHwzEx66OWFV2IP9dk    The Others                RIKA
# 15061  004s3t0ONYlzxII9PLgU6z  I Feel Alive       Steady Rollin
# 2887   008MceT31RotUANsKuzy3L   Liquid Blue  The.madpix.project
# 1029   008rk8F6ZxspZT4bUlkIQG         Fever         YOSA & TAAR
#
#        track_popularity          track_album_id track_album_name  \
# 12644                41  1srJQ0njEQgd8w4XSqI4JQ             Trip
# 25675                15  1ficfUnZMaY1QkNp15Slzm       The Others
# 15061                28  3z04Lb9Dsilqw68SHt6jLB      Love & Loss
# 2887                 24  1Z4ANBVuhTlS6DprlP0m1q      Liquid Blue
# 1029                 38  2BuYm9UcKvI0ydXs5JKwt0            Fever
#
#                        playlist_name             playlist_id playlist_genre  \
# 12644             Pinoy Classic Rock  37i9dQZF1DWYDQ8wBxd7xt           rock
# 25675    Groovy // Funky // Neo-Soul  0JmBB9HfrzDiZoPVRdv8ns            r&b
# 15061              Hard Rock Workout  3YouF0u7waJnolytf9JCXf           rock
# 2887                Electropop - Pop  5TiiHps0hNCyQ6ijVkNZQs            pop
# 1029   Best of 2019 Dance Pop: Japan  37i9dQZF1DXdOtZGKonFlM            pop
#
#       playlist_subgenre  ...  mode  speechiness  acousticness  \
# 12644      classic rock  ...     1       0.0236      0.279000
# 25675          neo soul  ...     1       0.0347      0.065100
# 15061         hard rock  ...     1       0.0442      0.011700
# 2887         electropop  ...     0       0.0540      0.000761
# 1029          dance pop  ...     1       0.0499      0.114000
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 12644          0.011700    0.0887    0.566   97.091       235440
# 25675          0.000000    0.2120    0.698  150.863       197286
# 15061          0.009940    0.3470    0.404  135.225       373512
# 2887           0.132000    0.3220    0.852  128.041       228565
# 1029           0.000697    0.0881    0.496  129.884       236308
#
#        track_album_release_year  track_album_release_month
# 12644                    2001.0                        1.0
# 25675                    2018.0                        1.0
# 15061                    2017.0                       11.0
# 2887                     2015.0                        8.0
# 1029                     2018.0                       11.0
#
# [5 rows x 24 columns]

# %%
df.describe().T
# Out:
#                              count           mean           std          min  \
# track_popularity           28356.0      39.329771     23.702376     0.000000
# danceability               28356.0       0.653372      0.145785     0.000000
# energy                     28356.0       0.698388      0.183503     0.000175
# key                        28356.0       5.368000      3.613904     0.000000
# loudness                   28356.0      -6.817696      3.036243   -46.448000
# mode                       28356.0       0.565489      0.495701     0.000000
# speechiness                28356.0       0.107954      0.102556     0.000000
# acousticness               28356.0       0.177176      0.222803     0.000000
# instrumentalness           28356.0       0.091117      0.232548     0.000000
# liveness                   28356.0       0.190958      0.155894     0.000000
# valence                    28356.0       0.510387      0.234340     0.000000
# tempo                      28356.0     120.956180     26.954560     0.000000
# duration_ms                28356.0  226575.967026  61078.450819  4000.000000
# track_album_release_year   26675.0    2012.103505     10.246302  1957.000000
# track_album_release_month  26675.0       6.418069      3.735760     1.000000
#
#                                      25%            50%           75%  \
# track_popularity               21.000000      42.000000      58.00000
# danceability                    0.561000       0.670000       0.76000
# energy                          0.579000       0.722000       0.84300
# key                             2.000000       6.000000       9.00000
# loudness                       -8.309250      -6.261000      -4.70900
# mode                            0.000000       1.000000       1.00000
# speechiness                     0.041000       0.062600       0.13300
# acousticness                    0.014375       0.079700       0.26000
# instrumentalness                0.000000       0.000021       0.00657
# liveness                        0.092600       0.127000       0.24900
# valence                         0.329000       0.512000       0.69500
# tempo                          99.972000     121.993000     133.99900
# duration_ms                187742.000000  216933.000000  254975.25000
# track_album_release_year     2010.000000    2016.000000    2019.00000
# track_album_release_month       3.000000       7.000000      10.00000
#
#                                   max
# track_popularity              100.000
# danceability                    0.983
# energy                          1.000
# key                            11.000
# loudness                        1.275
# mode                            1.000
# speechiness                     0.918
# acousticness                    0.994
# instrumentalness                0.994
# liveness                        0.996
# valence                         0.991
# tempo                         239.440
# duration_ms                517810.000
# track_album_release_year     2020.000
# track_album_release_month      12.000

# %%
# Check for missing values in all columns
missing_values = df.isnull().sum()

# Display the result
print(missing_values)
# Out:
# track_id                        0
# track_name                      4
# track_artist                    4
# track_popularity                0
# track_album_id                  0
# track_album_name                4
# playlist_name                   0
# playlist_id                     0
# playlist_genre                  0
# playlist_subgenre               0
# danceability                    0
# energy                          0
# key                             0
# loudness                        0
# mode                            0
# speechiness                     0
# acousticness                    0
# instrumentalness                0
# liveness                        0
# valence                         0
# tempo                           0
# duration_ms                     0
# track_album_release_year     1681
# track_album_release_month    1681
# dtype: int64

# %%
# Display all rows with missing values
df[df.isnull().any(axis=1)]
# Out:
#                      track_id                             track_name  \
# 12529  00qOE7OjRl0BpYiCiweZB2                          Juke Box Hero
# 20572  01QhVHvkGqzO861Kl3GhfX           I'll Be All You'll Ever Need
# 24300  01gSIlj7mZnuRr7GWajrgT                            Try My Love
# 14108  01q4ccXbvPlCwZ1fPiFaeM   Girlfriend in a Coma - 2011 Remaster
# 6865   02GwPAncasVL82yC7y2hmN                               Raise Up
# ...                       ...                                    ...
# 1699   7zHRcLHhkdkVDSwR0CKdLB                   All the Pretty Girls
# 8332   7zKZwfo5J4KA2vBpQHfQWp                     Heart Of A Hustler
# 14082  7zSAI7Ae6DPVepN8MksKVZ                    Space Age Love Song
# 11615  7zSDDsIlks515d0tZGM64x  The Next Time I Fall (with Amy Grant)
# 18035  7zsNAP0yvZq3aeIoAfyQj6                        Fruta Prohibida
#
#               track_artist  track_popularity          track_album_id  \
# 12529            Foreigner                67  2Pw51hAGvWpTA3AYl2WVuu
# 20572              Trinere                27  5BC8h7zzDUifrb8PJJ4UTM
# 24300            Shinehead                32  3pcdxm6Bp0nrOFQdYkZnWp
# 14108           The Smiths                56  7jfexk2w5aDI25njkN0UGg
# 6865           Petey Pablo                54  5HRSHdifYk7QXStjKB0SJZ
# ...                    ...               ...                     ...
# 1699                  fun.                42  6CsgMETT9H9NzcQSMD4Dfq
# 8332               Fat Pat                 0  2rzVFboUmXKVqSr0WDHmGR
# 14082  A Flock Of Seagulls                50  48ajNqhmdKrGVwJo0UGMiV
# 11615         Peter Cetera                57  1O2sEdKLsSHROEyYgUQmnb
# 18035   Dragon & Caballero                53  3bTxKb6I54lCSPkP385Ko8
#
#                        track_album_name  \
# 12529                      4 (Expanded)
# 20572                         All Night
# 24300               Sidewalk University
# 14108         Strangeways, Here We Come
# 6865       Diary of a Sinner: 1st Entry
# ...                                 ...
# 1699                     Aim and Ignite
# 8332                      Greatest Hits
# 14082                   We Are The '80s
# 11615              Solitude / Solitaire
# 18035  Se Siente Bien (Special Edition)
#
#                                            playlist_name  \
# 12529                                 Classic Rock Drive
# 20572  80's Freestyle/Disco Dance Party (Set Crossfad...
# 24300                                90's NEW JACK SWING
# 14108                                     permanent wave
# 6865                                    Southern Hip Hop
# ...                                                  ...
# 1699                            Pop Punk | Post-Hardcore
# 8332                                  3rd Coast Classics
# 14082                                     permanent wave
# 11615               80s Pop & Rock Hits and Album Tracks
# 18035                                  Latin Pop antiguo
#
#                   playlist_id playlist_genre playlist_subgenre  ...  mode  \
# 12529  37i9dQZF1DXdOEFt9ZX0dh           rock      classic rock  ...     1
# 20572  1oReEujyWpQv2OX68BVPPA          latin     latin hip hop  ...     0
# 24300  0dmInkymNnOTWvEFamSNzb            r&b    new jack swing  ...     0
# 14108  7rPsfDTqiZYIT4PVzQ4c0c           rock    permanent wave  ...     1
# 6865   4lcyWQDOzPfcbZrcBI3FOW            rap  southern hip hop  ...     1
# ...                       ...            ...               ...  ...   ...
# 1699   1YgWQAs1s77NzieIH4ARKn            pop     post-teen pop  ...     1
# 8332   1QJ66s6YBZgxMUaVUyrhbo            rap  southern hip hop  ...     1
# 14082  7rPsfDTqiZYIT4PVzQ4c0c           rock    permanent wave  ...     1
# 11615  0XOIK4m26aeYSD61E5nSVW           rock        album rock  ...     1
# 18035  4BmnnqWEQAamNoVjtjrQJP          latin         latin pop  ...     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 12529       0.0654      0.082800          0.000000    0.0844    0.522
# 20572       0.0546      0.007940          0.000290    0.0619    0.770
# 24300       0.1130      0.194000          0.000000    0.0761    0.752
# 14108       0.0255      0.126000          0.000001    0.0995    0.960
# 6865        0.1670      0.142000          0.000000    0.3190    0.742
# ...            ...           ...               ...       ...      ...
# 1699        0.0602      0.258000          0.000000    0.1990    0.773
# 8332        0.2740      0.026600          0.000000    0.1690    0.684
# 14082       0.0311      0.000036          0.106000    0.2100    0.552
# 11615       0.0280      0.488000          0.002210    0.0645    0.368
# 18035       0.0668      0.035200          0.000000    0.0979    0.829
#
#          tempo  duration_ms  track_album_release_year  \
# 12529  176.647       259800                       NaN
# 20572  123.551       324360                       NaN
# 24300  103.307       264893                       NaN
# 14108  104.333       122760                       NaN
# 6865   156.069       286427                       NaN
# ...        ...          ...                       ...
# 1699   131.036       202893                       NaN
# 8332   168.403       326267                       NaN
# 14082  139.959       226693                       NaN
# 11615  118.288       225973                       NaN
# 18035   91.997       222133                       NaN
#
#        track_album_release_month
# 12529                        NaN
# 20572                        NaN
# 24300                        NaN
# 14108                        NaN
# 6865                         NaN
# ...                          ...
# 1699                         NaN
# 8332                         NaN
# 14082                        NaN
# 11615                        NaN
# 18035                        NaN
#
# [1685 rows x 24 columns]

# %%
df['track_popularity'].value_counts()
# Out:
# track_popularity
# 0      2620
# 1       546
# 51      484
# 57      479
# 50      474
#        ...
# 97        3
# 95        2
# 100       1
# 99        1
# 96        1
# Name: count, Length: 101, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'playlist_name', 'playlist_id',
#        'playlist_genre', 'playlist_subgenre', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms',
#        'track_album_release_year', 'track_album_release_month'],
#       dtype='object')

# %%
playlist_genre_counts = df['playlist_genre'].value_counts()

# Display the counts
print(playlist_genre_counts)
# Out:
# playlist_genre
# rap      5057
# r&b      4918
# edm      4877
# latin    4633
# rock     4451
# pop      4420
# Name: count, dtype: int64

# %%
playlist_subgenre_counts = df['playlist_subgenre'].value_counts()

# Display the counts
print(playlist_subgenre_counts)
# Out:
# playlist_subgenre
# southern hip hop             1512
# neo soul                     1496
# progressive electro house    1460
# indie poptimism              1457
# electro house                1416
# latin hip hop                1336
# urban contemporary           1323
# tropical                     1288
# gangster rap                 1285
# latin pop                    1230
# hard rock                    1211
# hip hop                      1190
# classic rock                 1142
# electropop                   1124
# trap                         1070
# album rock                   1065
# new jack swing               1057
# hip pop                      1042
# big room                     1034
# permanent wave               1033
# dance pop                    1000
# pop edm                       967
# post-teen pop                 839
# reggaeton                     779
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                      track_id    track_name        track_artist  \
# 12644  0017A6SJgTbfQVU2EtsPNo      Pangarap     Barbie's Cradle
# 25675  002xjHwzEx66OWFV2IP9dk    The Others                RIKA
# 15061  004s3t0ONYlzxII9PLgU6z  I Feel Alive       Steady Rollin
# 2887   008MceT31RotUANsKuzy3L   Liquid Blue  The.madpix.project
# 1029   008rk8F6ZxspZT4bUlkIQG         Fever         YOSA & TAAR
#
#        track_popularity          track_album_id track_album_name  \
# 12644                41  1srJQ0njEQgd8w4XSqI4JQ             Trip
# 25675                15  1ficfUnZMaY1QkNp15Slzm       The Others
# 15061                28  3z04Lb9Dsilqw68SHt6jLB      Love & Loss
# 2887                 24  1Z4ANBVuhTlS6DprlP0m1q      Liquid Blue
# 1029                 38  2BuYm9UcKvI0ydXs5JKwt0            Fever
#
#                        playlist_name             playlist_id playlist_genre  \
# 12644             Pinoy Classic Rock  37i9dQZF1DWYDQ8wBxd7xt           rock
# 25675    Groovy // Funky // Neo-Soul  0JmBB9HfrzDiZoPVRdv8ns            r&b
# 15061              Hard Rock Workout  3YouF0u7waJnolytf9JCXf           rock
# 2887                Electropop - Pop  5TiiHps0hNCyQ6ijVkNZQs            pop
# 1029   Best of 2019 Dance Pop: Japan  37i9dQZF1DXdOtZGKonFlM            pop
#
#       playlist_subgenre  ...  mode  speechiness  acousticness  \
# 12644      classic rock  ...     1       0.0236      0.279000
# 25675          neo soul  ...     1       0.0347      0.065100
# 15061         hard rock  ...     1       0.0442      0.011700
# 2887         electropop  ...     0       0.0540      0.000761
# 1029          dance pop  ...     1       0.0499      0.114000
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 12644          0.011700    0.0887    0.566   97.091       235440
# 25675          0.000000    0.2120    0.698  150.863       197286
# 15061          0.009940    0.3470    0.404  135.225       373512
# 2887           0.132000    0.3220    0.852  128.041       228565
# 1029           0.000697    0.0881    0.496  129.884       236308
#
#        track_album_release_year  track_album_release_month
# 12644                    2001.0                        1.0
# 25675                    2018.0                        1.0
# 15061                    2017.0                       11.0
# 2887                     2015.0                        8.0
# 1029                     2018.0                       11.0
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28356 entries, 12644 to 12608
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   track_id                   28356 non-null  string
#  1   track_name                 28352 non-null  string
#  2   track_artist               28352 non-null  string
#  3   track_popularity           28356 non-null  int64
#  4   track_album_id             28356 non-null  string
#  5   track_album_name           28352 non-null  string
#  6   playlist_name              28356 non-null  string
#  7   playlist_id                28356 non-null  string
#  8   playlist_genre             28356 non-null  category
#  9   playlist_subgenre          28356 non-null  category
#  10  danceability               28356 non-null  float64
#  11  energy                     28356 non-null  float64
#  12  key                        28356 non-null  int64
#  13  loudness                   28356 non-null  float64
#  14  mode                       28356 non-null  int64
#  15  speechiness                28356 non-null  float64
#  16  acousticness               28356 non-null  float64
#  17  instrumentalness           28356 non-null  float64
#  18  liveness                   28356 non-null  float64
#  19  valence                    28356 non-null  float64
#  20  tempo                      28356 non-null  float64
#  21  duration_ms                28356 non-null  int64
#  22  track_album_release_year   26675 non-null  float64
#  23  track_album_release_month  26675 non-null  float64
# dtypes: category(2), float64(11), int64(4), string(7)
# memory usage: 5.0 MB

# %%
num_unique_subgenres = df['playlist_subgenre'].nunique()
print(f"Number of unique subgenres: {num_unique_subgenres}")
# Out:
# Number of unique subgenres: 24

# %%
# Get the number of columns in the DataFrame
num_columns = df.shape[1]

# Print the number of columns
print(f"Number of columns in the DataFrame: {num_columns}")
# Out:
# Number of columns in the DataFrame: 24

# %%
# חשב את מספר הפעמים שכל playlist_id מופיע
playlist_counts = df.groupby('playlist_id').size()

# הצג את ה-DataFrame עם כמות השורות לכל playlist_id
print(playlist_counts)
# Out:
# playlist_id
# 0275i1VNfBnsNbPl0QIBpG    91
# 03qQtbNHoJuFezRu2CnLuF    12
# 03sDEv7FN58Mb9CJOs1Tgn    38
# 06zrBJ5cts5aemZmqe80J7    46
# 07SNJ4MwYba9wwmzrbjmYi    94
#                           ..
# 7sq6nuruoMyDhEWkX2oYOg    43
# 7tkgK1tm9hYkWp7EFyOcAr    27
# 7vJOXFe40axY7qS39vGDyH    19
# 7xWdFCrU5Gka6qp1ODrSdK    36
# 7xWuNevFBmwnFEg6wzdCc7    60
# Length: 471, dtype: int64

# %%
import pandas as pd
import string
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# Function to clean text (this will be used for all relevant columns)
def clean_text(text):
    if pd.isna(text):
        return ''  # If the text is NaN, return an empty string
    
    # Lowercase the text
    text = text.lower()
    
    # Remove punctuation (but keep numbers)
    text = ''.join([char for char in text if char not in string.punctuation])
    
    # Remove stop words (using sklearn's ENGLISH_STOP_WORDS or you can define your own list)
    text = ' '.join([word for word in text.split() if word not in ENGLISH_STOP_WORDS])
    
    return text

# Check if the columns exist before applying cleaning
if 'track_name' in df.columns:
    # Clean the 'track_name' column
    df['track_name'] = df['track_name'].apply(clean_text)
else:
    print("'track_name' column is not in the DataFrame")

if 'track_album_name' in df.columns:
    # Clean the 'track_album_name' column
    df['track_album_name'] = df['track_album_name'].apply(clean_text)
else:
    print("'track_album_name' column is not in the DataFrame")

if 'playlist_name' in df.columns:
    # Clean the 'playlist_name' column
    df['playlist_name'] = df['playlist_name'].apply(clean_text)
else:
    print("'playlist_name' column is not in the DataFrame")

if 'track_album_id' in df.columns:
    # Clean the 'track_album_id' column (if needed)
    df['track_album_id'] = df['track_album_id'].apply(clean_text)
else:
    print("'track_album_id' column is not in the DataFrame")

if 'track_artist' in df.columns:
    # Clean the 'track_artist' column
    df['track_artist'] = df['track_artist'].apply(clean_text)
else:
    print("'track_artist' column is not in the DataFrame")

# Step 1: Move cleaned columns from df to df1
df1 = df[['track_name', 'track_album_name', 'playlist_name']].copy()

# Step 2: Remove the cleaned columns from df
df.drop(columns=['track_name', 'track_album_name', 'playlist_name'], inplace=True)

# %%
df.head()
# Out:
#                      track_id      track_artist  track_popularity  \
# 12644  0017A6SJgTbfQVU2EtsPNo    barbies cradle                41
# 25675  002xjHwzEx66OWFV2IP9dk              rika                15
# 15061  004s3t0ONYlzxII9PLgU6z     steady rollin                28
# 2887   008MceT31RotUANsKuzy3L  themadpixproject                24
# 1029   008rk8F6ZxspZT4bUlkIQG         yosa taar                38
#
#                track_album_id             playlist_id playlist_genre  \
# 12644  1srjq0njeqgd8w4xsqi4jq  37i9dQZF1DWYDQ8wBxd7xt           rock
# 25675  1ficfunzmay1qknp15slzm  0JmBB9HfrzDiZoPVRdv8ns            r&b
# 15061  3z04lb9dsilqw68sht6jlb  3YouF0u7waJnolytf9JCXf           rock
# 2887   1z4anbvuhtls6dprlp0m1q  5TiiHps0hNCyQ6ijVkNZQs            pop
# 1029   2buym9uckvi0ydxs5jkwt0  37i9dQZF1DXdOtZGKonFlM            pop
#
#       playlist_subgenre  danceability  energy  key  ...  mode  speechiness  \
# 12644      classic rock         0.682   0.401    2  ...     1       0.0236
# 25675          neo soul         0.582   0.704    5  ...     1       0.0347
# 15061         hard rock         0.303   0.880    9  ...     1       0.0442
# 2887         electropop         0.659   0.794   10  ...     0       0.0540
# 1029          dance pop         0.662   0.838    1  ...     1       0.0499
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 12644      0.279000          0.011700    0.0887    0.566   97.091
# 25675      0.065100          0.000000    0.2120    0.698  150.863
# 15061      0.011700          0.009940    0.3470    0.404  135.225
# 2887       0.000761          0.132000    0.3220    0.852  128.041
# 1029       0.114000          0.000697    0.0881    0.496  129.884
#
#        duration_ms  track_album_release_year  track_album_release_month
# 12644       235440                    2001.0                        1.0
# 25675       197286                    2018.0                        1.0
# 15061       373512                    2017.0                       11.0
# 2887        228565                    2015.0                        8.0
# 1029        236308                    2018.0                       11.0
#
# [5 rows x 21 columns]

# %%
df1.head()
# Out:
#         track_name track_album_name              playlist_name
# 12644     pangarap             trip         pinoy classic rock
# 25675                                     groovy funky neosoul
# 15061   feel alive        love loss          hard rock workout
# 2887   liquid blue      liquid blue             electropop pop
# 1029         fever            fever  best 2019 dance pop japan

# %%
import pandas as pd

# Assuming df is your DataFrame
# Convert 'track_id' and 'playlist_id' to lowercase
if 'track_id' in df.columns:
    df['track_id'] = df['track_id'].str.lower()

if 'playlist_id' in df.columns:
    df['playlist_id'] = df['playlist_id'].str.lower()

# Now, 'track_id' and 'playlist_id' columns are in lowercase

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28356 entries, 12644 to 12608
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_name        28356 non-null  object
#  1   track_album_name  28356 non-null  object
#  2   playlist_name     28356 non-null  object
# dtypes: object(3)
# memory usage: 886.1+ KB

# %%
df.head()
# Out:
#                      track_id      track_artist  track_popularity  \
# 12644  0017a6sjgtbfqvu2etspno    barbies cradle                41
# 25675  002xjhwzex66owfv2ip9dk              rika                15
# 15061  004s3t0onylzxii9plgu6z     steady rollin                28
# 2887   008mcet31rotuanskuzy3l  themadpixproject                24
# 1029   008rk8f6zxspzt4bulkiqg         yosa taar                38
#
#                track_album_id             playlist_id playlist_genre  \
# 12644  1srjq0njeqgd8w4xsqi4jq  37i9dqzf1dwydq8wbxd7xt           rock
# 25675  1ficfunzmay1qknp15slzm  0jmbb9hfrzdizopvrdv8ns            r&b
# 15061  3z04lb9dsilqw68sht6jlb  3youf0u7wajnolytf9jcxf           rock
# 2887   1z4anbvuhtls6dprlp0m1q  5tiihps0hncyq6ijvknzqs            pop
# 1029   2buym9uckvi0ydxs5jkwt0  37i9dqzf1dxdotzgkonflm            pop
#
#       playlist_subgenre  danceability  energy  key  ...  mode  speechiness  \
# 12644      classic rock         0.682   0.401    2  ...     1       0.0236
# 25675          neo soul         0.582   0.704    5  ...     1       0.0347
# 15061         hard rock         0.303   0.880    9  ...     1       0.0442
# 2887         electropop         0.659   0.794   10  ...     0       0.0540
# 1029          dance pop         0.662   0.838    1  ...     1       0.0499
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 12644      0.279000          0.011700    0.0887    0.566   97.091
# 25675      0.065100          0.000000    0.2120    0.698  150.863
# 15061      0.011700          0.009940    0.3470    0.404  135.225
# 2887       0.000761          0.132000    0.3220    0.852  128.041
# 1029       0.114000          0.000697    0.0881    0.496  129.884
#
#        duration_ms  track_album_release_year  track_album_release_month
# 12644       235440                    2001.0                        1.0
# 25675       197286                    2018.0                        1.0
# 15061       373512                    2017.0                       11.0
# 2887        228565                    2015.0                        8.0
# 1029        236308                    2018.0                       11.0
#
# [5 rows x 21 columns]

# %%
df1['track_name'] = df1['track_name'].astype('string')
df1['track_album_name'] = df1['track_album_name'].astype('string')
df1['playlist_name'] = df1['playlist_name'].astype('string')
df['track_album_id'] = df['track_album_id'].astype('string')
df['track_artist'] = df['track_artist'].astype('string')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28356 entries, 12644 to 12608
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_name        28356 non-null  string
#  1   track_album_name  28356 non-null  string
#  2   playlist_name     28356 non-null  string
# dtypes: string(3)
# memory usage: 886.1 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28356 entries, 12644 to 12608
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   track_id                   28356 non-null  string
#  1   track_artist               28356 non-null  string
#  2   track_popularity           28356 non-null  int64
#  3   track_album_id             28356 non-null  string
#  4   playlist_id                28356 non-null  string
#  5   playlist_genre             28356 non-null  category
#  6   playlist_subgenre          28356 non-null  category
#  7   danceability               28356 non-null  float64
#  8   energy                     28356 non-null  float64
#  9   key                        28356 non-null  int64
#  10  loudness                   28356 non-null  float64
#  11  mode                       28356 non-null  int64
#  12  speechiness                28356 non-null  float64
#  13  acousticness               28356 non-null  float64
#  14  instrumentalness           28356 non-null  float64
#  15  liveness                   28356 non-null  float64
#  16  valence                    28356 non-null  float64
#  17  tempo                      28356 non-null  float64
#  18  duration_ms                28356 non-null  int64
#  19  track_album_release_year   26675 non-null  float64
#  20  track_album_release_month  26675 non-null  float64
# dtypes: category(2), float64(11), int64(4), string(4)
# memory usage: 4.4 MB

# %%
# Step 1: Move the 'playlist_subgenre' column from df to df1
df1['playlist_subgenre'] = df['playlist_subgenre']

# Step 2: Remove the 'playlist_subgenre' column from df
df = df.drop(columns=['playlist_subgenre'])

# %%
df
# Out:
#                      track_id          track_artist  track_popularity  \
# 12644  0017a6sjgtbfqvu2etspno        barbies cradle                41
# 25675  002xjhwzex66owfv2ip9dk                  rika                15
# 15061  004s3t0onylzxii9plgu6z         steady rollin                28
# 2887   008mcet31rotuanskuzy3l      themadpixproject                24
# 1029   008rk8f6zxspzt4bulkiqg             yosa taar                38
# ...                       ...                   ...               ...
# 22211  7zxrmhxxjmqceddg0rkavo                   nav                72
# 24247  7zylobyw4qukqdyzob4j0y             father mc                36
# 3793   7zycspvjdcqh6yt1fel2ky           nicki minaj                49
# 26767  7zye9v6b785efwefys13c2  ponderosa twins plus                40
# 12608  7zzzmpw8l66zpjh1m6qmos            moonstar88                61
#
#                track_album_id             playlist_id playlist_genre  \
# 12644  1srjq0njeqgd8w4xsqi4jq  37i9dqzf1dwydq8wbxd7xt           rock
# 25675  1ficfunzmay1qknp15slzm  0jmbb9hfrzdizopvrdv8ns            r&b
# 15061  3z04lb9dsilqw68sht6jlb  3youf0u7wajnolytf9jcxf           rock
# 2887   1z4anbvuhtls6dprlp0m1q  5tiihps0hncyq6ijvknzqs            pop
# 1029   2buym9uckvi0ydxs5jkwt0  37i9dqzf1dxdotzgkonflm            pop
# ...                       ...                     ...            ...
# 22211  4jr29cnw14zc4z5vflxkoj  6haci9bqaiuszedfcemwyo            r&b
# 24247  14hymxfhpgdir9cci1u0kt  4sji14lrb5bgcr51lpalyh            r&b
# 3793   5qs8t6zhsrnllnouuk6muc  1keczikzh8igawt2biapxz            pop
# 26767  1xdglmtfmsyjyi5djoox7t  5emarioe9z9ekoewiac2jw            r&b
# 12608  4t3ftecyv1gclhmpbhxsfb  37i9dqzf1dwydq8wbxd7xt           rock
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 12644         0.682   0.401    2   -10.068     1       0.0236      0.279000
# 25675         0.582   0.704    5    -6.242     1       0.0347      0.065100
# 15061         0.303   0.880    9    -4.739     1       0.0442      0.011700
# 2887          0.659   0.794   10    -5.644     0       0.0540      0.000761
# 1029          0.662   0.838    1    -6.300     1       0.0499      0.114000
# ...             ...     ...  ...       ...   ...          ...           ...
# 22211         0.744   0.715    0    -6.103     1       0.3510      0.101000
# 24247         0.832   0.666    1    -4.920     0       0.0633      0.143000
# 3793          0.963   0.603    2    -6.224     1       0.1800      0.067300
# 26767         0.458   0.540    5    -6.457     0       0.0270      0.715000
# 12608         0.664   0.537    2    -6.000     1       0.0290      0.217000
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 12644          0.011700    0.0887    0.566   97.091       235440
# 25675          0.000000    0.2120    0.698  150.863       197286
# 15061          0.009940    0.3470    0.404  135.225       373512
# 2887           0.132000    0.3220    0.852  128.041       228565
# 1029           0.000697    0.0881    0.496  129.884       236308
# ...                 ...       ...      ...      ...          ...
# 22211          0.000000    0.0919    0.340  154.962       179773
# 24247          0.000000    0.0720    0.810  109.536       223890
# 3793           0.000006    0.2140    0.647  129.990       260240
# 26767          0.000428    0.1150    0.657  142.218       191205
# 12608          0.000003    0.1180    0.221  115.049       267960
#
#        track_album_release_year  track_album_release_month
# 12644                    2001.0                        1.0
# 25675                    2018.0                        1.0
# 15061                    2017.0                       11.0
# 2887                     2015.0                        8.0
# 1029                     2018.0                       11.0
# ...                         ...                        ...
# 22211                    2017.0                        2.0
# 24247                    2010.0                       10.0
# 3793                     2014.0                       12.0
# 26767                    2013.0                        7.0
# 12608                    2008.0                        7.0
#
# [28356 rows x 20 columns]

# %%
import pandas as pd

# Step 1: Count the occurrences of each genre per track_id
genre_counts = df.groupby(['track_id', 'playlist_genre']).size().reset_index(name='genre_count')

# Step 2: Identify the most popular playlist_genre for each track_id
most_popular_genre = genre_counts.loc[genre_counts.groupby('track_id')['genre_count'].idxmax()]

# Step 3: Merge the most popular genre information back into the original DataFrame
df_with_popular_genre = df.merge(most_popular_genre[['track_id', 'playlist_genre']], on=['track_id', 'playlist_genre'], how='left')

# Step 4: Remove duplicates, keeping only the row with the most popular genre for each track_id
df_unique_tracks = df_with_popular_genre.drop_duplicates(subset='track_id', keep='first')

# Step 5: Optionally, display the result
print(df_unique_tracks.head())
# Out:
#                  track_id      track_artist  track_popularity  \
# 0  0017a6sjgtbfqvu2etspno    barbies cradle                41
# 1  002xjhwzex66owfv2ip9dk              rika                15
# 2  004s3t0onylzxii9plgu6z     steady rollin                28
# 3  008mcet31rotuanskuzy3l  themadpixproject                24
# 4  008rk8f6zxspzt4bulkiqg         yosa taar                38
#
#            track_album_id             playlist_id playlist_genre  \
# 0  1srjq0njeqgd8w4xsqi4jq  37i9dqzf1dwydq8wbxd7xt           rock
# 1  1ficfunzmay1qknp15slzm  0jmbb9hfrzdizopvrdv8ns            r&b
# 2  3z04lb9dsilqw68sht6jlb  3youf0u7wajnolytf9jcxf           rock
# 3  1z4anbvuhtls6dprlp0m1q  5tiihps0hncyq6ijvknzqs            pop
# 4  2buym9uckvi0ydxs5jkwt0  37i9dqzf1dxdotzgkonflm            pop
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.682   0.401    2   -10.068     1       0.0236      0.279000
# 1         0.582   0.704    5    -6.242     1       0.0347      0.065100
# 2         0.303   0.880    9    -4.739     1       0.0442      0.011700
# 3         0.659   0.794   10    -5.644     0       0.0540      0.000761
# 4         0.662   0.838    1    -6.300     1       0.0499      0.114000
#
#    instrumentalness  liveness  valence    tempo  duration_ms  \
# 0          0.011700    0.0887    0.566   97.091       235440
# 1          0.000000    0.2120    0.698  150.863       197286
# 2          0.009940    0.3470    0.404  135.225       373512
# 3          0.132000    0.3220    0.852  128.041       228565
# 4          0.000697    0.0881    0.496  129.884       236308
#
#    track_album_release_year  track_album_release_month
# 0                    2001.0                        1.0
# 1                    2018.0                        1.0
# 2                    2017.0                       11.0
# 3                    2015.0                        8.0
# 4                    2018.0                       11.0

# %%
df.head()
# Out:
#                      track_id      track_artist  track_popularity  \
# 12644  0017a6sjgtbfqvu2etspno    barbies cradle                41
# 25675  002xjhwzex66owfv2ip9dk              rika                15
# 15061  004s3t0onylzxii9plgu6z     steady rollin                28
# 2887   008mcet31rotuanskuzy3l  themadpixproject                24
# 1029   008rk8f6zxspzt4bulkiqg         yosa taar                38
#
#                track_album_id             playlist_id playlist_genre  \
# 12644  1srjq0njeqgd8w4xsqi4jq  37i9dqzf1dwydq8wbxd7xt           rock
# 25675  1ficfunzmay1qknp15slzm  0jmbb9hfrzdizopvrdv8ns            r&b
# 15061  3z04lb9dsilqw68sht6jlb  3youf0u7wajnolytf9jcxf           rock
# 2887   1z4anbvuhtls6dprlp0m1q  5tiihps0hncyq6ijvknzqs            pop
# 1029   2buym9uckvi0ydxs5jkwt0  37i9dqzf1dxdotzgkonflm            pop
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 12644         0.682   0.401    2   -10.068     1       0.0236      0.279000
# 25675         0.582   0.704    5    -6.242     1       0.0347      0.065100
# 15061         0.303   0.880    9    -4.739     1       0.0442      0.011700
# 2887          0.659   0.794   10    -5.644     0       0.0540      0.000761
# 1029          0.662   0.838    1    -6.300     1       0.0499      0.114000
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 12644          0.011700    0.0887    0.566   97.091       235440
# 25675          0.000000    0.2120    0.698  150.863       197286
# 15061          0.009940    0.3470    0.404  135.225       373512
# 2887           0.132000    0.3220    0.852  128.041       228565
# 1029           0.000697    0.0881    0.496  129.884       236308
#
#        track_album_release_year  track_album_release_month
# 12644                    2001.0                        1.0
# 25675                    2018.0                        1.0
# 15061                    2017.0                       11.0
# 2887                     2015.0                        8.0
# 1029                     2018.0                       11.0

# %%
df.head()
# Out:
#                      track_id      track_artist  track_popularity  \
# 12644  0017a6sjgtbfqvu2etspno    barbies cradle                41
# 25675  002xjhwzex66owfv2ip9dk              rika                15
# 15061  004s3t0onylzxii9plgu6z     steady rollin                28
# 2887   008mcet31rotuanskuzy3l  themadpixproject                24
# 1029   008rk8f6zxspzt4bulkiqg         yosa taar                38
#
#                track_album_id             playlist_id playlist_genre  \
# 12644  1srjq0njeqgd8w4xsqi4jq  37i9dqzf1dwydq8wbxd7xt           rock
# 25675  1ficfunzmay1qknp15slzm  0jmbb9hfrzdizopvrdv8ns            r&b
# 15061  3z04lb9dsilqw68sht6jlb  3youf0u7wajnolytf9jcxf           rock
# 2887   1z4anbvuhtls6dprlp0m1q  5tiihps0hncyq6ijvknzqs            pop
# 1029   2buym9uckvi0ydxs5jkwt0  37i9dqzf1dxdotzgkonflm            pop
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 12644         0.682   0.401    2   -10.068     1       0.0236      0.279000
# 25675         0.582   0.704    5    -6.242     1       0.0347      0.065100
# 15061         0.303   0.880    9    -4.739     1       0.0442      0.011700
# 2887          0.659   0.794   10    -5.644     0       0.0540      0.000761
# 1029          0.662   0.838    1    -6.300     1       0.0499      0.114000
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 12644          0.011700    0.0887    0.566   97.091       235440
# 25675          0.000000    0.2120    0.698  150.863       197286
# 15061          0.009940    0.3470    0.404  135.225       373512
# 2887           0.132000    0.3220    0.852  128.041       228565
# 1029           0.000697    0.0881    0.496  129.884       236308
#
#        track_album_release_year  track_album_release_month
# 12644                    2001.0                        1.0
# 25675                    2018.0                        1.0
# 15061                    2017.0                       11.0
# 2887                     2015.0                        8.0
# 1029                     2018.0                       11.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28356 entries, 12644 to 12608
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   track_id                   28356 non-null  string
#  1   track_artist               28356 non-null  string
#  2   track_popularity           28356 non-null  int64
#  3   track_album_id             28356 non-null  string
#  4   playlist_id                28356 non-null  string
#  5   playlist_genre             28356 non-null  category
#  6   danceability               28356 non-null  float64
#  7   energy                     28356 non-null  float64
#  8   key                        28356 non-null  int64
#  9   loudness                   28356 non-null  float64
#  10  mode                       28356 non-null  int64
#  11  speechiness                28356 non-null  float64
#  12  acousticness               28356 non-null  float64
#  13  instrumentalness           28356 non-null  float64
#  14  liveness                   28356 non-null  float64
#  15  valence                    28356 non-null  float64
#  16  tempo                      28356 non-null  float64
#  17  duration_ms                28356 non-null  int64
#  18  track_album_release_year   26675 non-null  float64
#  19  track_album_release_month  26675 non-null  float64
# dtypes: category(1), float64(11), int64(4), string(4)
# memory usage: 4.4 MB

# %%
df1
# Out:
#                           track_name               track_album_name  \
# 12644                       pangarap                           trip
# 25675
# 15061                     feel alive                      love loss
# 2887                     liquid blue                    liquid blue
# 1029                           fever                          fever
# ...                              ...                            ...
# 22211                            way                            nav
# 24247  ill 4 u rerecorded remastered  ill 4 u rerecorded remastered
# 3793                        anaconda       pinkprint deluxe edition
# 26767                          bound       221 digitally remastered
# 12608                       migraine                            met
#
#                           playlist_name   playlist_subgenre
# 12644                pinoy classic rock        classic rock
# 25675              groovy funky neosoul            neo soul
# 15061                 hard rock workout           hard rock
# 2887                     electropop pop          electropop
# 1029          best 2019 dance pop japan           dance pop
# ...                                 ...                 ...
# 22211              project contemporary  urban contemporary
# 24247  new jack swing rb hits 1987 2002      new jack swing
# 3793                      10er playlist          electropop
# 26767                    sexy soul 2020            neo soul
# 12608                pinoy classic rock        classic rock
#
# [28356 rows x 4 columns]

# %%
import pickle
#Write a pickle file
with open('popularity.pkl', 'wb') as f:
    pickle.dump(df, f)

# %%
# Check missing values in a specific column
print(df.isnull().sum())
# Out:
# track_id                        0
# track_artist                    0
# track_popularity                0
# track_album_id                  0
# playlist_id                     0
# playlist_genre                  0
# danceability                    0
# energy                          0
# key                             0
# loudness                        0
# mode                            0
# speechiness                     0
# acousticness                    0
# instrumentalness                0
# liveness                        0
# valence                         0
# tempo                           0
# duration_ms                     0
# track_album_release_year     1681
# track_album_release_month    1681
# dtype: int64

# %%
df.playlist_genre.unique()
# Out:
# ['rock', 'r&b', 'pop', 'latin', 'edm', 'rap']
# Categories (6, object): ['edm' < 'rap' < 'pop' < 'r&b' < 'latin' < 'rock']

# %%
# Save df and df1 to CSV files with proper file extensions
df.to_csv('spotify_df_after_data_prep.csv', index=False)  # Adding .csv extension
df1.to_csv('spotify_df1_after_data_prep.csv', index=False)  # Adding .csv extension

# Save df and df1 to Pickle files
df.to_pickle('spotify_df_after_data_prep.pkl')  # Saving as .pkl
df1.to_pickle('spotify_df1_after_data_prep.pkl')  # Saving as .pkl

# Print confirmation
print("Spotify dataset saved as CSV and Pickle files.")
# Out:
# Spotify dataset saved as CSV and Pickle files.

# %%
df1.head()
# Out:
#         track_name track_album_name              playlist_name  \
# 12644     pangarap             trip         pinoy classic rock
# 25675                                     groovy funky neosoul
# 15061   feel alive        love loss          hard rock workout
# 2887   liquid blue      liquid blue             electropop pop
# 1029         fever            fever  best 2019 dance pop japan
#
#       playlist_subgenre
# 12644      classic rock
# 25675          neo soul
# 15061         hard rock
# 2887         electropop
# 1029          dance pop

# %%
df.head()
# Out:
#                      track_id      track_artist  track_popularity  \
# 12644  0017a6sjgtbfqvu2etspno    barbies cradle                41
# 25675  002xjhwzex66owfv2ip9dk              rika                15
# 15061  004s3t0onylzxii9plgu6z     steady rollin                28
# 2887   008mcet31rotuanskuzy3l  themadpixproject                24
# 1029   008rk8f6zxspzt4bulkiqg         yosa taar                38
#
#                track_album_id             playlist_id playlist_genre  \
# 12644  1srjq0njeqgd8w4xsqi4jq  37i9dqzf1dwydq8wbxd7xt           rock
# 25675  1ficfunzmay1qknp15slzm  0jmbb9hfrzdizopvrdv8ns            r&b
# 15061  3z04lb9dsilqw68sht6jlb  3youf0u7wajnolytf9jcxf           rock
# 2887   1z4anbvuhtls6dprlp0m1q  5tiihps0hncyq6ijvknzqs            pop
# 1029   2buym9uckvi0ydxs5jkwt0  37i9dqzf1dxdotzgkonflm            pop
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 12644         0.682   0.401    2   -10.068     1       0.0236      0.279000
# 25675         0.582   0.704    5    -6.242     1       0.0347      0.065100
# 15061         0.303   0.880    9    -4.739     1       0.0442      0.011700
# 2887          0.659   0.794   10    -5.644     0       0.0540      0.000761
# 1029          0.662   0.838    1    -6.300     1       0.0499      0.114000
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 12644          0.011700    0.0887    0.566   97.091       235440
# 25675          0.000000    0.2120    0.698  150.863       197286
# 15061          0.009940    0.3470    0.404  135.225       373512
# 2887           0.132000    0.3220    0.852  128.041       228565
# 1029           0.000697    0.0881    0.496  129.884       236308
#
#        track_album_release_year  track_album_release_month
# 12644                    2001.0                        1.0
# 25675                    2018.0                        1.0
# 15061                    2017.0                       11.0
# 2887                     2015.0                        8.0
# 1029                     2018.0                       11.0

# %%
df.shape
# Out:
# (28356, 20)
