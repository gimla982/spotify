# %%
#!pip install pandas
import pandas as pd
#!pip install numpy
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
# Attempt to read the file with a different encoding, such as 'ISO-8859-1' or 'latin1'
df = pd.read_csv(r"C:\Users\info\spotify\StateProvincesTableFromMSWWID2016.csv", encoding='ISO-8859-1')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
#  13  key                       32833 non-null  int64
#  14  loudness                  32833 non-null  float64
#  15  mode                      32833 non-null  int64
#  16  speechiness               32833 non-null  float64
#  17  acousticness              32833 non-null  float64
#  18  instrumentalness          32833 non-null  float64
#  19  liveness                  32833 non-null  float64
#  20  valence                   32833 non-null  float64
#  21  tempo                     32833 non-null  float64
#  22  duration_ms               32833 non-null  int64
# dtypes: float64(9), int64(4), object(10)
# memory usage: 5.8+ MB

# %%
# Keep only one occurrence of each unique 'track_id' and drop the rest
df = df.drop_duplicates(subset='track_id', keep='first')

# Count the number of unique 'track_id' values after filtering
unique_track_ids = df['track_id'].nunique()

# Display the result
print(f"Number of unique track_ids: {unique_track_ids}")
print(f"DataFrame after keeping only the unique track_ids:\n{df.head()}")
# Out:
# Number of unique track_ids: 28356
# DataFrame after keeping only the unique track_ids:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               14/06/2019
# 1                    Memories (Dillon Francis Remix)               13/12/2019
# 2                    All the Time (Don Diablo Remix)               05/07/2019
# 3                        Call You Mine - The Remixes               19/07/2019
# 4            Someone You Loved (Future Humans Remix)               05/03/2019
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7    -3.778
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -4.672
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583        0.1020          0.000000    0.0653    0.518
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
# 3     1       0.1020        0.0287          0.000009    0.2040    0.277
# 4     1       0.0359        0.0803          0.000000    0.0833    0.725
#
#      tempo  duration_ms
# 0  122.036       194754
# 1   99.972       162600
# 2  124.008       176616
# 3  121.956       169093
# 4  123.976       189052
#
# [5 rows x 23 columns]

# %%
df=df_unique
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25190 entries, 3 to 32832
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  25190 non-null  string
#  1   track_name                25187 non-null  string
#  2   track_artist              25187 non-null  string
#  3   track_popularity          25190 non-null  int64
#  4   track_album_id            25190 non-null  string
#  5   track_album_name          25187 non-null  string
#  6   track_album_release_date  23683 non-null  datetime64[ns]
#  7   playlist_name             25190 non-null  string
#  8   playlist_id               25190 non-null  string
#  9   playlist_genre            25190 non-null  category
#  10  playlist_subgenre         25190 non-null  category
#  11  danceability              25190 non-null  float64
#  12  energy                    25190 non-null  float64
#  13  key                       25190 non-null  int64
#  14  loudness                  25190 non-null  float64
#  15  mode                      25190 non-null  int64
#  16  speechiness               25190 non-null  float64
#  17  acousticness              25190 non-null  float64
#  18  instrumentalness          25190 non-null  float64
#  19  liveness                  25190 non-null  float64
#  20  valence                   25190 non-null  float64
#  21  tempo                     25190 non-null  float64
#  22  duration_ms               25190 non-null  int64
#  23  duplicates                25190 non-null  int64
# dtypes: category(2), datetime64[ns](1), float64(9), int64(5), string(7)
# memory usage: 4.5 MB

# %%
# Get the number of columns in the DataFrame
num_columns = df.shape[1]

# Print the number of columns
print(f"Number of columns in the DataFrame: {num_columns}")
# Out:
# Number of columns in the DataFrame: 24

# %%
# Get unique values in the 'playlist_genre' column
unique_genres = df['playlist_genre'].unique()

# Display the unique genres
print(unique_genres)
# Out:
# ['pop', 'rap', 'rock', 'latin', 'r&b', 'edm']
# Categories (6, object): ['edm', 'latin', 'pop', 'r&b', 'rap', 'rock']

# %%
df['track_id'] = df['track_id'].astype('string')
df['track_name'] = df['track_name'].astype('string')
df['track_artist'] = df['track_artist'].astype('string')
df['track_album_id'] = df['track_album_id'].astype('string')
df['track_album_name'] = df['track_album_name'].astype('string')
df['track_album_release_date'] = pd.to_datetime(df['track_album_release_date'], errors='coerce')
df['playlist_name'] = df['playlist_name'].astype('string')
df['playlist_id'] = df['playlist_id'].astype('string')
df['playlist_genre'] = df['playlist_genre'].astype('category')
df['playlist_subgenre'] = df['playlist_subgenre'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25190 entries, 3 to 32832
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  25190 non-null  string
#  1   track_name                25187 non-null  string
#  2   track_artist              25187 non-null  string
#  3   track_popularity          25190 non-null  int64
#  4   track_album_id            25190 non-null  string
#  5   track_album_name          25187 non-null  string
#  6   track_album_release_date  23683 non-null  datetime64[ns]
#  7   playlist_name             25190 non-null  string
#  8   playlist_id               25190 non-null  string
#  9   playlist_genre            25190 non-null  category
#  10  playlist_subgenre         25190 non-null  category
#  11  danceability              25190 non-null  float64
#  12  energy                    25190 non-null  float64
#  13  key                       25190 non-null  int64
#  14  loudness                  25190 non-null  float64
#  15  mode                      25190 non-null  int64
#  16  speechiness               25190 non-null  float64
#  17  acousticness              25190 non-null  float64
#  18  instrumentalness          25190 non-null  float64
#  19  liveness                  25190 non-null  float64
#  20  valence                   25190 non-null  float64
#  21  tempo                     25190 non-null  float64
#  22  duration_ms               25190 non-null  int64
#  23  duplicates                25190 non-null  int64
# dtypes: category(2), datetime64[ns](1), float64(9), int64(5), string(7)
# memory usage: 4.5 MB

# %%
df.describe().T
# Out:
#                             count                           mean  \
# track_popularity          25190.0                       37.10794
# track_album_release_date    23683  2012-08-16 17:23:26.527889152
# danceability              25190.0                       0.652559
# energy                    25190.0                       0.697178
# key                       25190.0                       5.374395
# loudness                  25190.0                      -6.896591
# mode                      25190.0                       0.564113
# speechiness               25190.0                       0.108713
# acousticness              25190.0                       0.179709
# instrumentalness          25190.0                       0.095998
# liveness                  25190.0                       0.191432
# valence                   25190.0                       0.510365
# tempo                     25190.0                     120.981311
# duration_ms               25190.0                  226843.724732
# duplicates                25190.0                            0.0
#
#                                           min                  25%  \
# track_popularity                          0.0                 19.0
# track_album_release_date  1957-01-01 00:00:00  2010-01-01 00:00:00
# danceability                              0.0                 0.56
# energy                               0.000175                0.577
# key                                       0.0                  2.0
# loudness                              -46.448               -8.412
# mode                                      0.0                  0.0
# speechiness                               0.0                0.041
# acousticness                              0.0               0.0141
# instrumentalness                          0.0                  0.0
# liveness                                  0.0               0.0925
# valence                                   0.0                0.328
# tempo                                     0.0               99.976
# duration_ms                            4000.0             187539.5
# duplicates                                0.0                  0.0
#
#                                           50%                  75%  \
# track_popularity                         40.0                 55.0
# track_album_release_date  2016-10-21 00:00:00  2019-03-29 00:00:00
# danceability                            0.669                 0.76
# energy                                  0.721                0.844
# key                                       6.0                  9.0
# loudness                              -6.3455               -4.764
# mode                                      1.0                  1.0
# speechiness                            0.0627                0.135
# acousticness                           0.0802                0.265
# instrumentalness                     0.000025             0.008108
# liveness                                0.127                0.249
# valence                                 0.512                0.695
# tempo                                 121.994              134.057
# duration_ms                          217200.0             255413.0
# duplicates                                0.0                  0.0
#
#                                           max           std
# track_popularity                         90.0     22.750319
# track_album_release_date  2020-01-29 00:00:00           NaN
# danceability                            0.983      0.146274
# energy                                    1.0      0.185624
# key                                      11.0      3.614849
# loudness                                1.275      3.068494
# mode                                      1.0      0.495882
# speechiness                             0.918      0.103691
# acousticness                            0.994       0.22594
# instrumentalness                        0.994      0.238703
# liveness                                0.996      0.157258
# valence                                 0.991      0.235183
# tempo                                  239.44     26.994157
# duration_ms                          517810.0  61983.810649
# duplicates                                0.0           0.0

# %%
# Check for missing values in all columns
missing_values = df.isnull().sum()

# Display the result
print(missing_values)
# Out:
# track_id                       0
# track_name                     3
# track_artist                   3
# track_popularity               0
# track_album_id                 0
# track_album_name               3
# track_album_release_date    1507
# playlist_name                  0
# playlist_id                    0
# playlist_genre                 0
# playlist_subgenre              0
# danceability                   0
# energy                         0
# key                            0
# loudness                       0
# mode                           0
# speechiness                    0
# acousticness                   0
# instrumentalness               0
# liveness                       0
# valence                        0
# tempo                          0
# duration_ms                    0
# duplicates                     0
# dtype: int64

# %%
df['track_popularity'].value_counts()
# Out:
# track_popularity
# 0     2538
# 1      518
# 51     460
# 50     453
# 49     450
#       ...
# 86       8
# 88       6
# 90       4
# 89       3
# 87       2
# Name: count, Length: 91, dtype: int64

# %%
df['track_popularity'].value_counts()
# Out:
# track_popularity
# 0     2538
# 1      518
# 51     460
# 50     453
# 49     450
#       ...
# 86       8
# 88       6
# 90       4
# 89       3
# 87       2
# Name: count, Length: 91, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'duplicates'],
#       dtype='object')

# %%
playlist_genre_counts = df['playlist_genre'].value_counts()

# Display the counts
print(playlist_genre_counts)
# Out:
# playlist_genre
# rap      4827
# edm      4513
# r&b      4270
# pop      3988
# rock     3862
# latin    3730
# Name: count, dtype: int64

# %%
playlist_subgenre_counts = df['playlist_subgenre'].value_counts()

# Display the counts
print(playlist_subgenre_counts)
# Out:
# playlist_subgenre
# neo soul                     1478
# progressive electro house    1460
# indie poptimism              1419
# southern hip hop             1413
# gangster rap                 1251
# hard rock                    1199
# electro house                1160
# latin hip hop                1159
# hip hop                      1114
# tropical                     1095
# trap                         1049
# electropop                   1031
# urban contemporary           1028
# new jack swing               1018
# pop edm                       947
# big room                      946
# permanent wave                940
# classic rock                  890
# latin pop                     866
# album rock                    833
# dance pop                     789
# post-teen pop                 749
# hip pop                       746
# reggaeton                     610
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                   track_id                                         track_name  \
# 3   75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4   1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
# 6   2OAylPUDDfwRGfe0lYqlCQ                    Never Really Over - R3HAB Remix
# 10  3eFJI470ALf1EYjywPRsJy  Cross Me (feat. Chance the Rapper & PnB Rock) ...
# 12  6e0CvGZf7CouOpYF8toXHC                                         Body On My
#
#         track_artist  track_popularity          track_album_id  \
# 3   The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4      Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
# 6         Katy Perry                62  7INHYSeusaFlyrHSNxm8qH
# 10        Ed Sheeran                58  49bXZtlI5kQSqQMSCnSaWO
# 12       Loud Luxury                67  2R66I0nzp3NnuUlzIGWQ5P
#
#                                      track_album_name  \
# 3                         Call You Mine - The Remixes
# 4             Someone You Loved (Future Humans Remix)
# 6                     Never Really Over (R3HAB Remix)
# 10  Cross Me (feat. Chance the Rapper & PnB Rock) ...
# 12                                         Body On My
#
#    track_album_release_date playlist_name             playlist_id  \
# 3                2019-07-19     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 4                2019-03-05     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 6                2019-07-26     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 10               2019-06-21     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 12               2019-03-29     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
#
#    playlist_genre  ... loudness  mode  speechiness  acousticness  \
# 3             pop  ...   -3.778     1       0.1020        0.0287
# 4             pop  ...   -4.672     1       0.0359        0.0803
# 6             pop  ...   -4.788     0       0.0623        0.1870
# 10            pop  ...   -6.500     1       0.1810        0.1460
# 12            pop  ...   -4.675     1       0.0463        0.0399
#
#     instrumentalness  liveness  valence    tempo  duration_ms  duplicates
# 3           0.000009    0.2040    0.277  121.956       169093           0
# 4           0.000000    0.0833    0.725  123.976       189052           0
# 6           0.000000    0.1760    0.152  112.648       187675           0
# 10          0.000005    0.1240    0.752  121.984       207894           0
# 12          0.000000    0.3740    0.687  121.985       192507           0
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25190 entries, 3 to 32832
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  25190 non-null  string
#  1   track_name                25187 non-null  string
#  2   track_artist              25187 non-null  string
#  3   track_popularity          25190 non-null  int64
#  4   track_album_id            25190 non-null  string
#  5   track_album_name          25187 non-null  string
#  6   track_album_release_date  23683 non-null  datetime64[ns]
#  7   playlist_name             25190 non-null  string
#  8   playlist_id               25190 non-null  string
#  9   playlist_genre            25190 non-null  category
#  10  playlist_subgenre         25190 non-null  category
#  11  danceability              25190 non-null  float64
#  12  energy                    25190 non-null  float64
#  13  key                       25190 non-null  int64
#  14  loudness                  25190 non-null  float64
#  15  mode                      25190 non-null  int64
#  16  speechiness               25190 non-null  float64
#  17  acousticness              25190 non-null  float64
#  18  instrumentalness          25190 non-null  float64
#  19  liveness                  25190 non-null  float64
#  20  valence                   25190 non-null  float64
#  21  tempo                     25190 non-null  float64
#  22  duration_ms               25190 non-null  int64
#  23  duplicates                25190 non-null  int64
# dtypes: category(2), datetime64[ns](1), float64(9), int64(5), string(7)
# memory usage: 4.5 MB

# %%
num_unique_subgenres = df['playlist_subgenre'].nunique()
print(f"Number of unique subgenres: {num_unique_subgenres}")
# Out:
# Number of unique subgenres: 24

# %%
# Get the number of columns in the DataFrame
num_columns = df.shape[1]

# Print the number of columns
print(f"Number of columns in the DataFrame: {num_columns}")
# Out:
# Number of columns in the DataFrame: 24

# %%
import pandas as pd

# Assuming 'df' is your original DataFrame

# Step 1: Create dummy variables for the 'playlist_genre' column
df_dummies = pd.get_dummies(df['playlist_genre'], prefix='playlist_genre', drop_first=False)

# Step 2: Add the dummy columns to df
df = pd.concat([df, df_dummies], axis=1)

# Step 3: Move 'playlist_genre' to df1 and remove it from df
df1 = df[['playlist_genre']].copy()  # Move the 'playlist_genre' column to df1
df.drop(columns=['playlist_genre'], inplace=True)  # Remove 'playlist_genre' from df

# Optionally, print the first few rows of df to check the result
print(df.head())
# Optionally, print the first few rows of df1 to check the result
df.info()
# Out:
#                   track_id                                         track_name  \
# 3   75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4   1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
# 6   2OAylPUDDfwRGfe0lYqlCQ                    Never Really Over - R3HAB Remix
# 10  3eFJI470ALf1EYjywPRsJy  Cross Me (feat. Chance the Rapper & PnB Rock) ...
# 12  6e0CvGZf7CouOpYF8toXHC                                         Body On My
#
#         track_artist  track_popularity          track_album_id  \
# 3   The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4      Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
# 6         Katy Perry                62  7INHYSeusaFlyrHSNxm8qH
# 10        Ed Sheeran                58  49bXZtlI5kQSqQMSCnSaWO
# 12       Loud Luxury                67  2R66I0nzp3NnuUlzIGWQ5P
#
#                                      track_album_name  \
# 3                         Call You Mine - The Remixes
# 4             Someone You Loved (Future Humans Remix)
# 6                     Never Really Over (R3HAB Remix)
# 10  Cross Me (feat. Chance the Rapper & PnB Rock) ...
# 12                                         Body On My
#
#    track_album_release_date playlist_name             playlist_id  \
# 3                2019-07-19     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 4                2019-03-05     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 6                2019-07-26     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 10               2019-06-21     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 12               2019-03-29     Pop Remix  37i9dQZF1DXcZDD7cfEKhW
#
#    playlist_subgenre  ...  valence    tempo  duration_ms  duplicates  \
# 3          dance pop  ...    0.277  121.956       169093           0
# 4          dance pop  ...    0.725  123.976       189052           0
# 6          dance pop  ...    0.152  112.648       187675           0
# 10         dance pop  ...    0.752  121.984       207894           0
# 12         dance pop  ...    0.687  121.985       192507           0
#
#     playlist_genre_edm  playlist_genre_latin  playlist_genre_pop  \
# 3                False                 False                True
# 4                False                 False                True
# 6                False                 False                True
# 10               False                 False                True
# 12               False                 False                True
#
#     playlist_genre_r&b  playlist_genre_rap  playlist_genre_rock
# 3                False               False                False
# 4                False               False                False
# 6                False               False                False
# 10               False               False                False
# 12               False               False                False
#
# [5 rows x 29 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 25190 entries, 3 to 32832
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  25190 non-null  string
#  1   track_name                25187 non-null  string
#  2   track_artist              25187 non-null  string
#  3   track_popularity          25190 non-null  int64
#  4   track_album_id            25190 non-null  string
#  5   track_album_name          25187 non-null  string
#  6   track_album_release_date  23683 non-null  datetime64[ns]
#  7   playlist_name             25190 non-null  string
#  8   playlist_id               25190 non-null  string
#  9   playlist_subgenre         25190 non-null  category
#  10  danceability              25190 non-null  float64
#  11  energy                    25190 non-null  float64
#  12  key                       25190 non-null  int64
#  13  loudness                  25190 non-null  float64
#  14  mode                      25190 non-null  int64
#  15  speechiness               25190 non-null  float64
#  16  acousticness              25190 non-null  float64
#  17  instrumentalness          25190 non-null  float64
#  18  liveness                  25190 non-null  float64
#  19  valence                   25190 non-null  float64
#  20  tempo                     25190 non-null  float64
#  21  duration_ms               25190 non-null  int64
#  22  duplicates                25190 non-null  int64
#  23  playlist_genre_edm        25190 non-null  bool
#  24  playlist_genre_latin      25190 non-null  bool
#  25  playlist_genre_pop        25190 non-null  bool
#  26  playlist_genre_r&b        25190 non-null  bool
#  27  playlist_genre_rap        25190 non-null  bool
#  28  playlist_genre_rock       25190 non-null  bool
# dtypes: bool(6), category(1), datetime64[ns](1), float64(9), int64(5), string(7)
# memory usage: 4.6 MB

# %%
df1['playlist_subgenre'], df = df['playlist_subgenre'], df.drop(columns=['playlist_subgenre'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25190 entries, 3 to 32832
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  25190 non-null  string
#  1   track_name                25187 non-null  string
#  2   track_artist              25187 non-null  string
#  3   track_popularity          25190 non-null  int64
#  4   track_album_id            25190 non-null  string
#  5   track_album_name          25187 non-null  string
#  6   track_album_release_date  23683 non-null  datetime64[ns]
#  7   playlist_name             25190 non-null  string
#  8   playlist_id               25190 non-null  string
#  9   danceability              25190 non-null  float64
#  10  energy                    25190 non-null  float64
#  11  key                       25190 non-null  int64
#  12  loudness                  25190 non-null  float64
#  13  mode                      25190 non-null  int64
#  14  speechiness               25190 non-null  float64
#  15  acousticness              25190 non-null  float64
#  16  instrumentalness          25190 non-null  float64
#  17  liveness                  25190 non-null  float64
#  18  valence                   25190 non-null  float64
#  19  tempo                     25190 non-null  float64
#  20  duration_ms               25190 non-null  int64
#  21  duplicates                25190 non-null  int64
#  22  playlist_genre_edm        25190 non-null  bool
#  23  playlist_genre_latin      25190 non-null  bool
#  24  playlist_genre_pop        25190 non-null  bool
#  25  playlist_genre_r&b        25190 non-null  bool
#  26  playlist_genre_rap        25190 non-null  bool
#  27  playlist_genre_rock       25190 non-null  bool
# dtypes: bool(6), datetime64[ns](1), float64(9), int64(5), string(7)
# memory usage: 4.6 MB

# %%
# חשב את מספר הפעמים שכל playlist_id מופיע
playlist_counts = df.groupby('playlist_id').size()

# הצג את ה-DataFrame עם כמות השורות לכל playlist_id
print(playlist_counts)
# Out:
# playlist_id
# 0275i1VNfBnsNbPl0QIBpG    77
# 03qQtbNHoJuFezRu2CnLuF     9
# 03sDEv7FN58Mb9CJOs1Tgn    25
# 06zrBJ5cts5aemZmqe80J7    38
# 07SNJ4MwYba9wwmzrbjmYi    93
#                           ..
# 7sq6nuruoMyDhEWkX2oYOg    37
# 7tkgK1tm9hYkWp7EFyOcAr    27
# 7vJOXFe40axY7qS39vGDyH    18
# 7xWdFCrU5Gka6qp1ODrSdK    25
# 7xWuNevFBmwnFEg6wzdCc7    45
# Length: 462, dtype: int64

# %%
import pandas as pd
import string
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# Function to clean text (this will be used for all relevant columns)
def clean_text(text):
    if pd.isna(text):
        return ''  # If the text is NaN, return an empty string
    
    # Lowercase the text
    text = text.lower()
    
    # Remove punctuation (but keep numbers)
    text = ''.join([char for char in text if char not in string.punctuation])
    
    # Remove stop words (using sklearn's ENGLISH_STOP_WORDS or you can define your own list)
    text = ' '.join([word for word in text.split() if word not in ENGLISH_STOP_WORDS])
    
    return text

# Check if the columns exist before applying cleaning
if 'track_name' in df.columns:
    # Clean the 'track_name' column
    df['track_name'] = df['track_name'].apply(clean_text)
else:
    print("'track_name' column is not in the DataFrame")

if 'track_album_name' in df.columns:
    # Clean the 'track_album_name' column
    df['track_album_name'] = df['track_album_name'].apply(clean_text)
else:
    print("'track_album_name' column is not in the DataFrame")

if 'playlist_name' in df.columns:
    # Clean the 'playlist_name' column
    df['playlist_name'] = df['playlist_name'].apply(clean_text)
else:
    print("'playlist_name' column is not in the DataFrame")

if 'track_album_id' in df.columns:
    # Clean the 'track_album_id' column (if needed)
    df['track_album_id'] = df['track_album_id'].apply(clean_text)
else:
    print("'track_album_id' column is not in the DataFrame")

# Step 1: Move cleaned columns from df to df1
df1 = df[['track_name', 'track_album_name', 'playlist_name', 'track_album_id']].copy()

# Step 2: Remove the columns from df
df.drop(columns=['track_name', 'track_album_name', 'playlist_name', 'track_album_id'], inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25190 entries, 3 to 32832
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_name        25190 non-null  object
#  1   track_album_name  25190 non-null  object
#  2   playlist_name     25190 non-null  object
#  3   track_album_id    25190 non-null  object
# dtypes: object(4)
# memory usage: 984.0+ KB

# %%
df.head()
# Out:
#                   track_id      track_artist  track_popularity  \
# 3   75FpbthrwQmzHlBJLuGdC7  The Chainsmokers                60
# 4   1e8PAfcKUYoKkxPhrHqw4x     Lewis Capaldi                69
# 6   2OAylPUDDfwRGfe0lYqlCQ        Katy Perry                62
# 10  3eFJI470ALf1EYjywPRsJy        Ed Sheeran                58
# 12  6e0CvGZf7CouOpYF8toXHC       Loud Luxury                67
#
#    track_album_release_date             playlist_id  danceability  energy  \
# 3                2019-07-19  37i9dQZF1DXcZDD7cfEKhW         0.718   0.930
# 4                2019-03-05  37i9dQZF1DXcZDD7cfEKhW         0.650   0.833
# 6                2019-07-26  37i9dQZF1DXcZDD7cfEKhW         0.449   0.856
# 10               2019-06-21  37i9dQZF1DXcZDD7cfEKhW         0.679   0.923
# 12               2019-03-29  37i9dQZF1DXcZDD7cfEKhW         0.744   0.726
#
#     key  loudness  mode  ...  valence    tempo  duration_ms  duplicates  \
# 3     7    -3.778     1  ...    0.277  121.956       169093           0
# 4     1    -4.672     1  ...    0.725  123.976       189052           0
# 6     5    -4.788     0  ...    0.152  112.648       187675           0
# 10    6    -6.500     1  ...    0.752  121.984       207894           0
# 12    1    -4.675     1  ...    0.687  121.985       192507           0
#
#     playlist_genre_edm  playlist_genre_latin  playlist_genre_pop  \
# 3                False                 False                True
# 4                False                 False                True
# 6                False                 False                True
# 10               False                 False                True
# 12               False                 False                True
#
#     playlist_genre_r&b  playlist_genre_rap  playlist_genre_rock
# 3                False               False                False
# 4                False               False                False
# 6                False               False                False
# 10               False               False                False
# 12               False               False                False
#
# [5 rows x 24 columns]

# %%
# Count the number of NaN values in the 'track_album_release_date' column
empty_cells_count = df['track_album_release_date'].isna().sum()

# Display the number of empty (NaN) cells
print(f"Number of empty cells in 'track_album_release_date': {empty_cells_count}")
# Out:
# Number of empty cells in 'track_album_release_date': 1507

# %%
import numpy as np

# Replace empty cells (None or blank) with NaN in 'track_album_release_date' column
df['track_album_release_date'] = df['track_album_release_date'].replace('', np.nan)

# Display the updated DataFrame
print(df[['track_album_release_date']])
# Out:
#       track_album_release_date
# 3                   2019-07-19
# 4                   2019-03-05
# 6                   2019-07-26
# 10                  2019-06-21
# 12                  2019-03-29
# ...                        ...
# 32828               2014-04-28
# 32829               2013-03-08
# 32830               2014-04-21
# 32831               2014-01-01
# 32832               2014-03-03
#
# [25190 rows x 1 columns]

# %%
df1['track_name'] = df1['track_name'].astype('string')
df1['track_album_name'] = df1['track_album_name'].astype('string')
df1['playlist_name'] = df1['playlist_name'].astype('string')
df1['track_album_id'] = df1['track_album_id'].astype('string')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25190 entries, 3 to 32832
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_name        25190 non-null  string
#  1   track_album_name  25190 non-null  string
#  2   playlist_name     25190 non-null  string
#  3   track_album_id    25190 non-null  string
# dtypes: string(4)
# memory usage: 984.0 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25190 entries, 3 to 32832
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  25190 non-null  string
#  1   track_artist              25187 non-null  string
#  2   track_popularity          25190 non-null  int64
#  3   track_album_release_date  23683 non-null  datetime64[ns]
#  4   playlist_id               25190 non-null  string
#  5   danceability              25190 non-null  float64
#  6   energy                    25190 non-null  float64
#  7   key                       25190 non-null  int64
#  8   loudness                  25190 non-null  float64
#  9   mode                      25190 non-null  int64
#  10  speechiness               25190 non-null  float64
#  11  acousticness              25190 non-null  float64
#  12  instrumentalness          25190 non-null  float64
#  13  liveness                  25190 non-null  float64
#  14  valence                   25190 non-null  float64
#  15  tempo                     25190 non-null  float64
#  16  duration_ms               25190 non-null  int64
#  17  duplicates                25190 non-null  int64
#  18  playlist_genre_edm        25190 non-null  bool
#  19  playlist_genre_latin      25190 non-null  bool
#  20  playlist_genre_pop        25190 non-null  bool
#  21  playlist_genre_r&b        25190 non-null  bool
#  22  playlist_genre_rap        25190 non-null  bool
#  23  playlist_genre_rock       25190 non-null  bool
# dtypes: bool(6), datetime64[ns](1), float64(9), int64(5), string(3)
# memory usage: 3.8 MB

# %%
df.to_csv('final_spotify_copy')

# %%
df.to_pickle('spotify_df_after_data_prep_5.2.25.pkl')
df=pd.read_pickle('spotify_df_after_data_prep_5.2.25.pkl')

# %%
import pickle
#Write a pickle file
with open('popularity.pkl', 'wb') as f:
    pickle.dump(df, f)

print("spotify dataset saved as a pickle file.")
# Out:
# spotify dataset saved as a pickle file.
