# %%
#!pip install pandas
import pandas as pd
#!pip install numpy
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
# Attempt to read the file with a different encoding, such as 'ISO-8859-1' or 'latin1'
df = pd.read_csv(r"C:\Users\info\spotify\StateProvincesTableFromMSWWID2016.csv", encoding='ISO-8859-1')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
#  13  key                       32833 non-null  int64
#  14  loudness                  32833 non-null  float64
#  15  mode                      32833 non-null  int64
#  16  speechiness               32833 non-null  float64
#  17  acousticness              32833 non-null  float64
#  18  instrumentalness          32833 non-null  float64
#  19  liveness                  32833 non-null  float64
#  20  valence                   32833 non-null  float64
#  21  tempo                     32833 non-null  float64
#  22  duration_ms               32833 non-null  int64
# dtypes: float64(9), int64(4), object(10)
# memory usage: 5.8+ MB

# %%
df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               14/06/2019
# 1                    Memories (Dillon Francis Remix)               13/12/2019
# 2                    All the Time (Don Diablo Remix)               05/07/2019
# 3                        Call You Mine - The Remixes               19/07/2019
# 4            Someone You Loved (Future Humans Remix)               05/03/2019
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7    -3.778
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -4.672
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583        0.1020          0.000000    0.0653    0.518
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
# 3     1       0.1020        0.0287          0.000009    0.2040    0.277
# 4     1       0.0359        0.0803          0.000000    0.0833    0.725
#
#      tempo  duration_ms
# 0  122.036       194754
# 1   99.972       162600
# 2  124.008       176616
# 3  121.956       169093
# 4  123.976       189052
#
# [5 rows x 23 columns]

# %%
# Get the number of columns in the DataFrame
num_columns = df.shape[1]

# Print the number of columns
print(f"Number of columns in the DataFrame: {num_columns}")
# Out:
# Number of columns in the DataFrame: 23

# %%
# Get unique values in the 'playlist_genre' column
unique_genres = df['playlist_genre'].unique()

# Display the unique genres
print(unique_genres)
# Out:
# ['pop' 'rap' 'rock' 'latin' 'r&b' 'edm']

# %%
df['track_id'] = df['track_id'].astype('string')
df['track_name'] = df['track_name'].astype('string')
df['track_artist'] = df['track_artist'].astype('string')
df['track_album_id'] = df['track_album_id'].astype('string')
df['track_album_name'] = df['track_album_name'].astype('string')
df['track_album_release_date'] = pd.to_datetime(df['track_album_release_date'], errors='coerce')
df['playlist_name'] = df['playlist_name'].astype('string')
df['playlist_id'] = df['playlist_id'].astype('string')
df['playlist_genre'] = df['playlist_genre'].astype('category')
df['playlist_subgenre'] = df['playlist_subgenre'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  string
#  1   track_name                32828 non-null  string
#  2   track_artist              32828 non-null  string
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  string
#  5   track_album_name          32828 non-null  string
#  6   track_album_release_date  30947 non-null  datetime64[ns]
#  7   playlist_name             32833 non-null  string
#  8   playlist_id               32833 non-null  string
#  9   playlist_genre            32833 non-null  category
#  10  playlist_subgenre         32833 non-null  category
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
#  13  key                       32833 non-null  int64
#  14  loudness                  32833 non-null  float64
#  15  mode                      32833 non-null  int64
#  16  speechiness               32833 non-null  float64
#  17  acousticness              32833 non-null  float64
#  18  instrumentalness          32833 non-null  float64
#  19  liveness                  32833 non-null  float64
#  20  valence                   32833 non-null  float64
#  21  tempo                     32833 non-null  float64
#  22  duration_ms               32833 non-null  int64
# dtypes: category(2), datetime64[ns](1), float64(9), int64(4), string(7)
# memory usage: 5.3 MB

# %%
df.describe().T
# Out:
#                             count                           mean  \
# track_popularity          32833.0                      42.477081
# track_album_release_date    30947  2012-09-09 04:27:27.668594688
# danceability              32833.0                        0.65485
# energy                    32833.0                       0.698619
# key                       32833.0                       5.374471
# loudness                  32833.0                      -6.719499
# mode                      32833.0                       0.565711
# speechiness               32833.0                       0.107068
# acousticness              32833.0                       0.175334
# instrumentalness          32833.0                       0.084747
# liveness                  32833.0                       0.190176
# valence                   32833.0                       0.510561
# tempo                     32833.0                     120.881132
# duration_ms               32833.0                  225799.811622
#
#                                           min                  25%  \
# track_popularity                          0.0                 24.0
# track_album_release_date  1957-01-01 00:00:00  2010-12-04 00:00:00
# danceability                              0.0                0.563
# energy                               0.000175                0.581
# key                                       0.0                  2.0
# loudness                              -46.448               -8.171
# mode                                      0.0                  0.0
# speechiness                               0.0                0.041
# acousticness                              0.0               0.0151
# instrumentalness                          0.0                  0.0
# liveness                                  0.0               0.0927
# valence                                   0.0                0.331
# tempo                                     0.0                99.96
# duration_ms                            4000.0             187819.0
#
#                                           50%                  75%  \
# track_popularity                         45.0                 62.0
# track_album_release_date  2017-01-27 00:00:00  2019-05-16 00:00:00
# danceability                            0.672                0.761
# energy                                  0.721                 0.84
# key                                       6.0                  9.0
# loudness                               -6.166               -4.645
# mode                                      1.0                  1.0
# speechiness                            0.0625                0.132
# acousticness                           0.0804                0.255
# instrumentalness                     0.000016              0.00483
# liveness                                0.127                0.248
# valence                                 0.512                0.693
# tempo                                 121.984              133.918
# duration_ms                          216000.0             253585.0
#
#                                           max           std
# track_popularity                        100.0     24.984074
# track_album_release_date  2020-01-29 00:00:00           NaN
# danceability                            0.983      0.145085
# energy                                    1.0       0.18091
# key                                      11.0      3.611657
# loudness                                1.275      2.988436
# mode                                      1.0      0.495671
# speechiness                             0.918      0.101314
# acousticness                            0.994      0.219633
# instrumentalness                        0.994       0.22423
# liveness                                0.996      0.154317
# valence                                 0.991      0.233146
# tempo                                  239.44     26.903624
# duration_ms                          517810.0  59834.006182

# %%
# Check for missing values in all columns
missing_values = df.isnull().sum()

# Display the result
print(missing_values)
# Out:
# track_id                       0
# track_name                     5
# track_artist                   5
# track_popularity               0
# track_album_id                 0
# track_album_name               5
# track_album_release_date    1886
# playlist_name                  0
# playlist_id                    0
# playlist_genre                 0
# playlist_subgenre              0
# danceability                   0
# energy                         0
# key                            0
# loudness                       0
# mode                           0
# speechiness                    0
# acousticness                   0
# instrumentalness               0
# liveness                       0
# valence                        0
# tempo                          0
# duration_ms                    0
# dtype: int64

# %%
df['track_popularity'].value_counts()
# Out:
# track_popularity
# 0      2703
# 1       575
# 57      541
# 60      514
# 51      514
#        ...
# 97       22
# 95       15
# 96        7
# 99        4
# 100       2
# Name: count, Length: 101, dtype: int64

# %%
df['track_popularity'].value_counts()
# Out:
# track_popularity
# 0      2703
# 1       575
# 57      541
# 60      514
# 51      514
#        ...
# 97       22
# 95       15
# 96        7
# 99        4
# 100       2
# Name: count, Length: 101, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
playlist_genre_counts = df['playlist_genre'].value_counts()

# Display the counts
print(playlist_genre_counts)
# Out:
# playlist_genre
# edm      6043
# rap      5746
# pop      5507
# r&b      5431
# latin    5155
# rock     4951
# Name: count, dtype: int64

# %%
playlist_subgenre_counts = df['playlist_subgenre'].value_counts()

# Display the counts
print(playlist_subgenre_counts)
# Out:
# playlist_subgenre
# progressive electro house    1809
# southern hip hop             1675
# indie poptimism              1672
# latin hip hop                1656
# neo soul                     1637
# pop edm                      1517
# electro house                1511
# hard rock                    1485
# gangster rap                 1458
# electropop                   1408
# urban contemporary           1405
# hip hop                      1322
# dance pop                    1298
# classic rock                 1296
# trap                         1291
# tropical                     1288
# latin pop                    1262
# hip pop                      1256
# big room                     1206
# new jack swing               1133
# post-teen pop                1129
# permanent wave               1105
# album rock                   1065
# reggaeton                     949
# Name: count, dtype: int64

# %%
# Step 1: Count how many times each 'track_id' appears in 'playlist_name'
duplicates_count = df.groupby('track_id')['playlist_name'].transform('count')

# Step 2: Add the 'duplicates' column to df with the count of duplicates for each 'track_id'
df['duplicates'] = duplicates_count

# Step 3: Move the 'playlist_name' column to a new DataFrame df1
df1 = df[['playlist_name']].copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  string
#  1   track_name                32828 non-null  string
#  2   track_artist              32828 non-null  string
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  string
#  5   track_album_name          32828 non-null  string
#  6   track_album_release_date  30947 non-null  datetime64[ns]
#  7   playlist_name             32833 non-null  string
#  8   playlist_id               32833 non-null  string
#  9   playlist_genre            32833 non-null  category
#  10  playlist_subgenre         32833 non-null  category
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
#  13  key                       32833 non-null  int64
#  14  loudness                  32833 non-null  float64
#  15  mode                      32833 non-null  int64
#  16  speechiness               32833 non-null  float64
#  17  acousticness              32833 non-null  float64
#  18  instrumentalness          32833 non-null  float64
#  19  liveness                  32833 non-null  float64
#  20  valence                   32833 non-null  float64
#  21  tempo                     32833 non-null  float64
#  22  duration_ms               32833 non-null  int64
#  23  duplicates                32833 non-null  int64
# dtypes: category(2), datetime64[ns](1), float64(9), int64(5), string(7)
# memory usage: 5.6 MB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   playlist_name  32833 non-null  string
# dtypes: string(1)
# memory usage: 256.6 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  string
#  1   track_name                32828 non-null  string
#  2   track_artist              32828 non-null  string
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  string
#  5   track_album_name          32828 non-null  string
#  6   track_album_release_date  30947 non-null  datetime64[ns]
#  7   playlist_name             32833 non-null  string
#  8   playlist_id               32833 non-null  string
#  9   playlist_genre            32833 non-null  category
#  10  playlist_subgenre         32833 non-null  category
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
#  13  key                       32833 non-null  int64
#  14  loudness                  32833 non-null  float64
#  15  mode                      32833 non-null  int64
#  16  speechiness               32833 non-null  float64
#  17  acousticness              32833 non-null  float64
#  18  instrumentalness          32833 non-null  float64
#  19  liveness                  32833 non-null  float64
#  20  valence                   32833 non-null  float64
#  21  tempo                     32833 non-null  float64
#  22  duration_ms               32833 non-null  int64
#  23  duplicates                32833 non-null  int64
# dtypes: category(2), datetime64[ns](1), float64(9), int64(5), string(7)
# memory usage: 5.6 MB

# %%
num_unique_subgenres = df['playlist_subgenre'].nunique()
print(f"Number of unique subgenres: {num_unique_subgenres}")
# Out:
# Number of unique subgenres: 24

# %%
# Get the number of columns in the DataFrame
num_columns = df.shape[1]

# Print the number of columns
print(f"Number of columns in the DataFrame: {num_columns}")
# Out:
# Number of columns in the DataFrame: 24

# %%
import pandas as pd
import string
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# Function to clean text (this will be used for all relevant columns)
def clean_text(text):
    if pd.isna(text):
        return ''  # If the text is NaN, return an empty string
    
    # Lowercase the text
    text = text.lower()
    
    # Remove punctuation (but keep numbers)
    text = ''.join([char for char in text if char not in string.punctuation])
    
    # Remove stop words (using sklearn's ENGLISH_STOP_WORDS or you can define your own list)
    text = ' '.join([word for word in text.split() if word not in ENGLISH_STOP_WORDS])
    
    return text

# Check if the columns exist before applying cleaning
if 'track_name' in df.columns:
    # Clean the 'track_name' column
    df['track_name'] = df['track_name'].apply(clean_text)
else:
    print("'track_name' column is not in the DataFrame")

if 'track_album_name' in df.columns:
    # Clean the 'track_album_name' column
    df['track_album_name'] = df['track_album_name'].apply(clean_text)
else:
    print("'track_album_name' column is not in the DataFrame")

if 'playlist_name' in df.columns:
    # Clean the 'playlist_name' column
    df['playlist_name'] = df['playlist_name'].apply(clean_text)
else:
    print("'playlist_name' column is not in the DataFrame")

if 'track_album_id' in df.columns:
    # Clean the 'track_album_id' column (if needed)
    df['track_album_id'] = df['track_album_id'].apply(clean_text)
else:
    print("'track_album_id' column is not in the DataFrame")

# Step 1: Move cleaned columns from df to df1
df1 = df[['track_name', 'track_album_name', 'playlist_name', 'track_album_id']].copy()

# Step 2: Remove the columns from df
df.drop(columns=['track_name', 'track_album_name', 'playlist_name', 'track_album_id'], inplace=True)

# %%
# Remove the 'playlist_subgenre' column from df and store it in a variable
playlist_subgenre_column = df.pop('playlist_subgenre')

# Add the removed column to df1
df1['playlist_subgenre'] = playlist_subgenre_column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  string
#  1   track_artist              32828 non-null  string
#  2   track_popularity          32833 non-null  int64
#  3   track_album_release_date  30947 non-null  datetime64[ns]
#  4   playlist_id               32833 non-null  string
#  5   playlist_genre            32833 non-null  category
#  6   danceability              32833 non-null  float64
#  7   energy                    32833 non-null  float64
#  8   key                       32833 non-null  int64
#  9   loudness                  32833 non-null  float64
#  10  mode                      32833 non-null  int64
#  11  speechiness               32833 non-null  float64
#  12  acousticness              32833 non-null  float64
#  13  instrumentalness          32833 non-null  float64
#  14  liveness                  32833 non-null  float64
#  15  valence                   32833 non-null  float64
#  16  tempo                     32833 non-null  float64
#  17  duration_ms               32833 non-null  int64
#  18  duplicates                32833 non-null  int64
# dtypes: category(1), datetime64[ns](1), float64(9), int64(5), string(3)
# memory usage: 4.5 MB

# %%
df
# Out:
#                      track_id      track_artist  track_popularity  \
# 0      6f807x0ima9a1j3VPbc7VN        Ed Sheeran                66
# 1      0r7CVbZTWZgbTCYdfa2P31          Maroon 5                67
# 2      1z1Hg7Vb0AhHDiEmnDE79l      Zara Larsson                70
# 3      75FpbthrwQmzHlBJLuGdC7  The Chainsmokers                60
# 4      1e8PAfcKUYoKkxPhrHqw4x     Lewis Capaldi                69
# ...                       ...               ...               ...
# 32828  7bxnKAamR3snQ1VGLuVfC1      Lush & Simon                42
# 32829  5Aevni09Em4575077nkWHz    Tegan and Sara                20
# 32830  7ImMqPP3Q1yfUHvsdn7wEo       Starkillers                14
# 32831  2m69mhnfQ1Oq6lGtXuYhgX            Mat Zo                15
# 32832  29zWqhca3zt5NsckZqDf6c      Julian Calor                27
#
#       track_album_release_date             playlist_id playlist_genre  \
# 0                   2019-06-14  37i9dQZF1DXcZDD7cfEKhW            pop
# 1                   2019-12-13  37i9dQZF1DXcZDD7cfEKhW            pop
# 2                   2019-07-05  37i9dQZF1DXcZDD7cfEKhW            pop
# 3                   2019-07-19  37i9dQZF1DXcZDD7cfEKhW            pop
# 4                   2019-03-05  37i9dQZF1DXcZDD7cfEKhW            pop
# ...                        ...                     ...            ...
# 32828               2014-04-28  6jI1gFr6ANFtT8MmTvA2Ux            edm
# 32829               2013-03-08  6jI1gFr6ANFtT8MmTvA2Ux            edm
# 32830               2014-04-21  6jI1gFr6ANFtT8MmTvA2Ux            edm
# 32831               2014-01-01  6jI1gFr6ANFtT8MmTvA2Ux            edm
# 32832               2014-03-03  6jI1gFr6ANFtT8MmTvA2Ux            edm
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.748   0.916    6    -2.634     1       0.0583      0.102000
# 1             0.726   0.815   11    -4.969     1       0.0373      0.072400
# 2             0.675   0.931    1    -3.432     0       0.0742      0.079400
# 3             0.718   0.930    7    -3.778     1       0.1020      0.028700
# 4             0.650   0.833    1    -4.672     1       0.0359      0.080300
# ...             ...     ...  ...       ...   ...          ...           ...
# 32828         0.428   0.922    2    -1.814     1       0.0936      0.076600
# 32829         0.522   0.786    0    -4.462     1       0.0420      0.001710
# 32830         0.529   0.821    6    -4.899     0       0.0481      0.108000
# 32831         0.626   0.888    2    -3.361     1       0.1090      0.007920
# 32832         0.603   0.884    5    -4.571     0       0.0385      0.000133
#
#        instrumentalness  liveness  valence    tempo  duration_ms  duplicates
# 0              0.000000    0.0653   0.5180  122.036       194754           2
# 1              0.004210    0.3570   0.6930   99.972       162600           2
# 2              0.000023    0.1100   0.6130  124.008       176616           3
# 3              0.000009    0.2040   0.2770  121.956       169093           1
# 4              0.000000    0.0833   0.7250  123.976       189052           1
# ...                 ...       ...      ...      ...          ...         ...
# 32828          0.000000    0.0668   0.2100  128.170       204375           1
# 32829          0.004270    0.3750   0.4000  128.041       353120           1
# 32830          0.000001    0.1500   0.4360  127.989       210112           1
# 32831          0.127000    0.3430   0.3080  128.008       367432           1
# 32832          0.341000    0.7420   0.0894  127.984       337500           1
#
# [32833 rows x 19 columns]

# %%
# Count the number of NaN values in the 'track_album_release_date' column
empty_cells_count = df['track_album_release_date'].isna().sum()

# Display the number of empty (NaN) cells
print(f"Number of empty cells in 'track_album_release_date': {empty_cells_count}")
# Out:
# Number of empty cells in 'track_album_release_date': 1886

# %%
import numpy as np

# Replace empty cells (None or blank) with NaN in 'track_album_release_date' column
df['track_album_release_date'] = df['track_album_release_date'].replace('', np.nan)

# Display the updated DataFrame
print(df[['track_album_release_date']])
# Out:
#       track_album_release_date
# 0                   2019-06-14
# 1                   2019-12-13
# 2                   2019-07-05
# 3                   2019-07-19
# 4                   2019-03-05
# ...                        ...
# 32828               2014-04-28
# 32829               2013-03-08
# 32830               2014-04-21
# 32831               2014-01-01
# 32832               2014-03-03
#
# [32833 rows x 1 columns]

# %%
df1['track_name'] = df1['track_name'].astype('string')
df1['track_album_name'] = df1['track_album_name'].astype('string')
df1['playlist_name'] = df1['playlist_name'].astype('string')
df1['track_album_id'] = df1['track_album_id'].astype('string')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   track_name         32833 non-null  string
#  1   track_album_name   32833 non-null  string
#  2   playlist_name      32833 non-null  string
#  3   track_album_id     32833 non-null  string
#  4   playlist_subgenre  32833 non-null  category
# dtypes: category(1), string(4)
# memory usage: 1.0 MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  string
#  1   track_artist              32828 non-null  string
#  2   track_popularity          32833 non-null  int64
#  3   track_album_release_date  30947 non-null  datetime64[ns]
#  4   playlist_id               32833 non-null  string
#  5   playlist_genre            32833 non-null  category
#  6   danceability              32833 non-null  float64
#  7   energy                    32833 non-null  float64
#  8   key                       32833 non-null  int64
#  9   loudness                  32833 non-null  float64
#  10  mode                      32833 non-null  int64
#  11  speechiness               32833 non-null  float64
#  12  acousticness              32833 non-null  float64
#  13  instrumentalness          32833 non-null  float64
#  14  liveness                  32833 non-null  float64
#  15  valence                   32833 non-null  float64
#  16  tempo                     32833 non-null  float64
#  17  duration_ms               32833 non-null  int64
#  18  duplicates                32833 non-null  int64
# dtypes: category(1), datetime64[ns](1), float64(9), int64(5), string(3)
# memory usage: 4.5 MB

# %%
# Remove duplicate rows based on all columns
df = df.drop_duplicates()

# Alternatively, if you want to remove duplicates based on specific columns (e.g., 'track_id' and 'playlist_id'):
# df = df.drop_duplicates(subset=['track_id', 'playlist_id'])

# To reset the index after dropping duplicates:
df.reset_index(drop=True, inplace=True)

# Check the result
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32510 entries, 0 to 32509
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32510 non-null  string
#  1   track_artist              32505 non-null  string
#  2   track_popularity          32510 non-null  int64
#  3   track_album_release_date  30630 non-null  datetime64[ns]
#  4   playlist_id               32510 non-null  string
#  5   playlist_genre            32510 non-null  category
#  6   danceability              32510 non-null  float64
#  7   energy                    32510 non-null  float64
#  8   key                       32510 non-null  int64
#  9   loudness                  32510 non-null  float64
#  10  mode                      32510 non-null  int64
#  11  speechiness               32510 non-null  float64
#  12  acousticness              32510 non-null  float64
#  13  instrumentalness          32510 non-null  float64
#  14  liveness                  32510 non-null  float64
#  15  valence                   32510 non-null  float64
#  16  tempo                     32510 non-null  float64
#  17  duration_ms               32510 non-null  int64
#  18  duplicates                32510 non-null  int64
# dtypes: category(1), datetime64[ns](1), float64(9), int64(5), string(3)
# memory usage: 4.5 MB

# %%
df.to_csv('final_spotify_copy')

# %%
df.to_pickle('spotify_df_after_data_prep_5.2.25.pkl')
df=pd.read_pickle('spotify_df_after_data_prep_5.2.25.pkl')

# %%
import pickle
#Write a pickle file
with open('popularity.pkl', 'wb') as f:
    pickle.dump(df, f)

print("spotify dataset saved as a pickle file.")
# Out:
# spotify dataset saved as a pickle file.
