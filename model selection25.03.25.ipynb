# %%
#Model Selection and Fine Tuning

# %%
import matplotlib as plt
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

import pandas as pd

# Load the DataFrames from pickle files
df = pd.read_pickle('spotify_df_after_data_eng_df.pkl')
df1 = pd.read_pickle('spotify_df1_after_data_eng_df1.pkl')
df2 = pd.read_pickle('spotify_df2_after_data_eng_df2.pkl')

# Load the DataFrames from CSV files
df_csv = pd.read_csv('spotify_df_after_eng_df.csv')
df1_csv = pd.read_csv('spotify_df_after_eng_df1.csv')
df2_csv = pd.read_csv('spotify_df_after_eng_df2.csv')

# Print confirmation messages
print("Spotify datasets loaded from pickle files:")
print(f"df: {df.shape}")
print(f"df1: {df1.shape}")
print(f"df2: {df2.shape}")

print("\nSpotify datasets loaded from CSV files:")
print(f"df_csv: {df_csv.shape}")
print(f"df1_csv: {df1_csv.shape}")
print(f"df2_csv: {df2_csv.shape}")
# Out:
# Spotify datasets loaded from pickle files:
# df: (1656, 26)
# df1: (1656, 7)
# df2: (1656, 25)
#
# Spotify datasets loaded from CSV files:
# df_csv: (1656, 26)
# df1_csv: (1656, 7)
# df2_csv: (1656, 25)

# %%
df.head()
# Out:
#                      track_id  track_popularity          track_album_id  \
# 12529  00qoe7ojrl0bpyiciwezb2                67  2pw51hagvwpta3ayl2wvuu
# 20572  01qhvhvkgqzo861kl3ghfx                27  5bc8h7zzduifrb8pjj4utm
# 24300  01gsilj7mznurr7gwajrgt                32  3pcdxm6bp0nrofqdykznwp
# 14108  01q4ccxbvplcwz1fpifaem                56  7jfexk2w5adi25njkn0ugg
# 6865   02gwpancasvl82yc7y2hmn                54  5hrshdifyk7qxstjkb0sjz
#
#                   playlist_id  danceability  energy  key  loudness  mode  \
# 12529  37i9dqzf1dxdoeft9zx0dh         0.357   0.653    9    -5.554     1
# 20572  1oreeujywpqv2ox68bvppa         0.720   0.814    8    -8.195     0
# 24300  0dminkymnnotwvefamsnzb         0.819   0.497    0   -15.495     0
# 14108  7rpsfdtqizyit4pvzq4c0c         0.680   0.626    7    -8.519     1
# 6865   4lcywqdozpfcbzrcbi3fow         0.735   0.844    1    -5.215     1
#
#        speechiness  ...  month_track_album_release_date  genre_edm  genre_rap  \
# 12529       0.0654  ...                               1          0          0
# 20572       0.0546  ...                               1          0          0
# 24300       0.1130  ...                               1          0          0
# 14108       0.0255  ...                               1          0          0
# 6865        0.1670  ...                               1          0          1
#
#        genre_pop  genre_r&b  genre_latin  genre_rock  release_date_category  \
# 12529          0          0            0           1              1960-1993
# 20572          0          0            1           0              1994-2007
# 24300          0          1            0           0              1960-1993
# 14108          0          0            0           1              1960-1993
# 6865           0          0            0           0              1994-2007
#
#        top_50_words_in_song  Top 50 words in artist
# 12529                     0                       1
# 20572                     0                       0
# 24300                     1                       0
# 14108                     1                       1
# 6865                      0                       0
#
# [5 rows x 26 columns]

# %%
df1.head()
# Out:
#                           track_name        track_album_name  \
# 12529                  juke box hero              4 expanded
# 20572                 ill youll need                   night
# 24300                       try love     sidewalk university
# 14108  girlfriend coma 2011 remaster        strangeways come
# 6865                           raise  diary sinner 1st entry
#
#                                            playlist_name playlist_subgenre  \
# 12529                                 classic rock drive      classic rock
# 20572  80s freestyledisco dance party set crossfade 4...     latin hip hop
# 24300                                 90s new jack swing    new jack swing
# 14108                                     permanent wave    permanent wave
# 6865                                    southern hip hop  southern hip hop
#
#                track_album_id             playlist_id track_artist
# 12529  2pw51hagvwpta3ayl2wvuu  37i9dqzf1dxdoeft9zx0dh    foreigner
# 20572  5bc8h7zzduifrb8pjj4utm  1oreeujywpqv2ox68bvppa      trinere
# 24300  3pcdxm6bp0nrofqdykznwp  0dminkymnnotwvefamsnzb    shinehead
# 14108  7jfexk2w5adi25njkn0ugg  7rpsfdtqizyit4pvzq4c0c       smiths
# 6865   5hrshdifyk7qxstjkb0sjz  4lcywqdozpfcbzrcbi3fow  petey pablo

# %%
df2.head()
# Out:
#                      track_id  track_popularity  danceability  energy  key  \
# 12529  00qoe7ojrl0bpyiciwezb2                67         0.357   0.653    9
# 20572  01qhvhvkgqzo861kl3ghfx                27         0.720   0.814    8
# 24300  01gsilj7mznurr7gwajrgt                32         0.819   0.497    0
# 14108  01q4ccxbvplcwz1fpifaem                56         0.680   0.626    7
# 6865   02gwpancasvl82yc7y2hmn                54         0.735   0.844    1
#
#        loudness  mode  speechiness  acousticness  instrumentalness  ...  \
# 12529    -5.554     1       0.0654       0.08280          0.000000  ...
# 20572    -8.195     0       0.0546       0.00794          0.000290  ...
# 24300   -15.495     0       0.1130       0.19400          0.000000  ...
# 14108    -8.519     1       0.0255       0.12600          0.000001  ...
# 6865     -5.215     1       0.1670       0.14200          0.000000  ...
#
#        genre_pop  genre_r&b  genre_latin  genre_rock  release_date_category  \
# 12529          0          0            0           1              1960-1993
# 20572          0          0            1           0              1994-2007
# 24300          0          1            0           0              1960-1993
# 14108          0          0            0           1              1960-1993
# 6865           0          0            0           0              1994-2007
#
#        top_50_words_in_song  Top 50 words in artist  male_artist  \
# 12529                     0                       1            1
# 20572                     0                       0            1
# 24300                     1                       0            1
# 14108                     1                       1            1
# 6865                      0                       0            1
#
#        female_artist band_artist
# 12529              0           0
# 20572              0           0
# 24300              0           0
# 14108              0           0
# 6865               0           0
#
# [5 rows x 25 columns]

# %%
df2.describe()
# Out:
#        track_popularity  danceability       energy          key     loudness  \
# count       1656.000000   1656.000000  1656.000000  1656.000000  1656.000000
# mean          35.812802      0.620877     0.694132     5.464976    -7.990454
# std           24.361427      0.158281     0.184293     3.576017     3.316209
# min            0.000000      0.165000     0.087400     0.000000   -23.035000
# 25%           12.000000      0.511750     0.566000     2.000000    -9.905500
# 50%           39.000000      0.637000     0.719500     6.000000    -7.441000
# 75%           57.000000      0.737250     0.839000     9.000000    -5.543750
# max           80.000000      0.968000     0.996000    11.000000    -0.773000
#
#               mode  speechiness  acousticness  instrumentalness     liveness  \
# count  1656.000000  1656.000000   1656.000000       1656.000000  1656.000000
# mean      0.637681     0.090634      0.165362          0.050018     0.191957
# std       0.480815     0.094018      0.213257          0.161412     0.157806
# min       0.000000     0.022500      0.000003          0.000000     0.016300
# 25%       0.000000     0.035400      0.012500          0.000000     0.085250
# 50%       1.000000     0.050300      0.068400          0.000028     0.127000
# 75%       1.000000     0.098225      0.234000          0.002580     0.267250
# max       1.000000     0.817000      0.955000          0.987000     0.983000
#
#        ...    genre_rap    genre_pop    genre_r&b  genre_latin   genre_rock  \
# count  ...  1656.000000  1656.000000  1656.000000  1656.000000  1656.000000
# mean   ...     0.149758     0.102657     0.190217     0.111111     0.405797
# std    ...     0.356942     0.303602     0.392591     0.314365     0.491194
# min    ...     0.000000     0.000000     0.000000     0.000000     0.000000
# 25%    ...     0.000000     0.000000     0.000000     0.000000     0.000000
# 50%    ...     0.000000     0.000000     0.000000     0.000000     0.000000
# 75%    ...     0.000000     0.000000     0.000000     0.000000     1.000000
# max    ...     1.000000     1.000000     1.000000     1.000000     1.000000
#
#        top_50_words_in_song  Top 50 words in artist  male_artist  \
# count           1656.000000             1656.000000  1656.000000
# mean               0.545290                0.258454     0.791063
# std                0.498095                0.437917     0.406672
# min                0.000000                0.000000     0.000000
# 25%                0.000000                0.000000     1.000000
# 50%                1.000000                0.000000     1.000000
# 75%                1.000000                1.000000     1.000000
# max                1.000000                1.000000     1.000000
#
#        female_artist  band_artist
# count    1656.000000  1656.000000
# mean        0.171498     0.025966
# std         0.377057     0.159082
# min         0.000000     0.000000
# 25%         0.000000     0.000000
# 50%         0.000000     0.000000
# 75%         0.000000     0.000000
# max         1.000000     1.000000
#
# [8 rows x 23 columns]

# %%
# Add 'track_id', 'track_album_id', and 'playlist_id' from df to df1
df1['track_id'] = df['track_id']
df1['track_album_id'] = df['track_album_id']
df1['playlist_id'] = df['playlist_id']

# Remove the 'track_id', 'track_album_id', and 'playlist_id' columns from df
df = df.drop(columns=['track_id', 'track_album_id', 'playlist_id'])

# Print to confirm the changes
print("Updated df:")
print(df.head())

print("Updated df1:")
print(df1.head())
# Out:
# Updated df:
#        track_popularity  danceability  energy  key  loudness  mode  \
# 12529                67         0.357   0.653    9    -5.554     1
# 20572                27         0.720   0.814    8    -8.195     0
# 24300                32         0.819   0.497    0   -15.495     0
# 14108                56         0.680   0.626    7    -8.519     1
# 6865                 54         0.735   0.844    1    -5.215     1
#
#        speechiness  acousticness  instrumentalness  liveness  ...  \
# 12529       0.0654       0.08280          0.000000    0.0844  ...
# 20572       0.0546       0.00794          0.000290    0.0619  ...
# 24300       0.1130       0.19400          0.000000    0.0761  ...
# 14108       0.0255       0.12600          0.000001    0.0995  ...
# 6865        0.1670       0.14200          0.000000    0.3190  ...
#
#        month_track_album_release_date  genre_edm  genre_rap  genre_pop  \
# 12529                               1          0          0          0
# 20572                               1          0          0          0
# 24300                               1          0          0          0
# 14108                               1          0          0          0
# 6865                                1          0          1          0
#
#        genre_r&b  genre_latin  genre_rock  release_date_category  \
# 12529          0            0           1              1960-1993
# 20572          0            1           0              1994-2007
# 24300          1            0           0              1960-1993
# 14108          0            0           1              1960-1993
# 6865           0            0           0              1994-2007
#
#        top_50_words_in_song  Top 50 words in artist
# 12529                     0                       1
# 20572                     0                       0
# 24300                     1                       0
# 14108                     1                       1
# 6865                      0                       0
#
# [5 rows x 23 columns]
# Updated df1:
#                           track_name        track_album_name  \
# 12529                  juke box hero              4 expanded
# 20572                 ill youll need                   night
# 24300                       try love     sidewalk university
# 14108  girlfriend coma 2011 remaster        strangeways come
# 6865                           raise  diary sinner 1st entry
#
#                                            playlist_name playlist_subgenre  \
# 12529                                 classic rock drive      classic rock
# 20572  80s freestyledisco dance party set crossfade 4...     latin hip hop
# 24300                                 90s new jack swing    new jack swing
# 14108                                     permanent wave    permanent wave
# 6865                                    southern hip hop  southern hip hop
#
#                track_album_id             playlist_id track_artist  \
# 12529  2pw51hagvwpta3ayl2wvuu  37i9dqzf1dxdoeft9zx0dh    foreigner
# 20572  5bc8h7zzduifrb8pjj4utm  1oreeujywpqv2ox68bvppa      trinere
# 24300  3pcdxm6bp0nrofqdykznwp  0dminkymnnotwvefamsnzb    shinehead
# 14108  7jfexk2w5adi25njkn0ugg  7rpsfdtqizyit4pvzq4c0c       smiths
# 6865   5hrshdifyk7qxstjkb0sjz  4lcywqdozpfcbzrcbi3fow  petey pablo
#
#                      track_id
# 12529  00qoe7ojrl0bpyiciwezb2
# 20572  01qhvhvkgqzo861kl3ghfx
# 24300  01gsilj7mznurr7gwajrgt
# 14108  01q4ccxbvplcwz1fpifaem
# 6865   02gwpancasvl82yc7y2hmn

# %%
#df2['danceability_energy'] = df2['danceability'] * df2['energy']
#df2['loudness_speechiness'] = df2['loudness'] * df2['speechiness']

# %%
#df2['loudness'] = np.log1p(df2['loudness'])  # Log transformation

# %%
df.head()
# Out:
#        track_popularity  danceability  energy  key  loudness  mode  \
# 12529                67         0.357   0.653    9    -5.554     1
# 20572                27         0.720   0.814    8    -8.195     0
# 24300                32         0.819   0.497    0   -15.495     0
# 14108                56         0.680   0.626    7    -8.519     1
# 6865                 54         0.735   0.844    1    -5.215     1
#
#        speechiness  acousticness  instrumentalness  liveness  ...  \
# 12529       0.0654       0.08280          0.000000    0.0844  ...
# 20572       0.0546       0.00794          0.000290    0.0619  ...
# 24300       0.1130       0.19400          0.000000    0.0761  ...
# 14108       0.0255       0.12600          0.000001    0.0995  ...
# 6865        0.1670       0.14200          0.000000    0.3190  ...
#
#        month_track_album_release_date  genre_edm  genre_rap  genre_pop  \
# 12529                               1          0          0          0
# 20572                               1          0          0          0
# 24300                               1          0          0          0
# 14108                               1          0          0          0
# 6865                                1          0          1          0
#
#        genre_r&b  genre_latin  genre_rock  release_date_category  \
# 12529          0            0           1              1960-1993
# 20572          0            1           0              1994-2007
# 24300          1            0           0              1960-1993
# 14108          0            0           1              1960-1993
# 6865           0            0           0              1994-2007
#
#        top_50_words_in_song  Top 50 words in artist
# 12529                     0                       1
# 20572                     0                       0
# 24300                     1                       0
# 14108                     1                       1
# 6865                      0                       0
#
# [5 rows x 23 columns]

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
import pandas as pd

# Assuming df2 is your dataset (make sure it's already loaded)
# Split the dataset into features (X) and target (y)
X = df2.drop(columns=['track_popularity'])
y = df2['track_popularity']

# Drop or encode non-numeric columns
X = X.drop(columns=['release_date_category', 'top_50_words_in_song', 'Top 50 words in artist'])

# One-hot encode categorical columns (if any remain)
X = pd.get_dummies(X, drop_first=True)

# Handle missing values if any using SimpleImputer
imputer = SimpleImputer(strategy='mean')  # You can also try 'median' or 'most_frequent' based on your data
X_imputed = imputer.fit_transform(X)

# Ensure that all data is numeric (float64)
X_imputed = pd.DataFrame(X_imputed, columns=X.columns)  # Convert back to DataFrame with original column names
X_imputed = X_imputed.apply(pd.to_numeric, errors='coerce')  # Convert all columns to numeric, replacing non-convertible values with NaN
X_imputed = X_imputed.fillna(X_imputed.mean())  # Fill NaN values with column means

# Scale the features using StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

# Split the data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Define the parameter grid for GridSearchCV
param_grid = {'n_estimators': [50, 100, 200], 'max_depth': [3, 5, 7]}

# Perform GridSearchCV for RandomForestRegressor
grid_search = GridSearchCV(RandomForestRegressor(), param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Print the best parameters found by GridSearchCV
print("Best Parameters from GridSearchCV:", grid_search.best_params_)
# Out:
# Best Parameters from GridSearchCV: {'max_depth': 3, 'n_estimators': 100}

# %%
df.head()
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 12529         0.357   0.653    9    -5.554     1       0.0654       0.08280
# 20572         0.720   0.814    8    -8.195     0       0.0546       0.00794
# 24300         0.819   0.497    0   -15.495     0       0.1130       0.19400
# 14108         0.680   0.626    7    -8.519     1       0.0255       0.12600
# 6865          0.735   0.844    1    -5.215     1       0.1670       0.14200
#
#        instrumentalness  liveness  valence  ...  \
# 12529          0.000000    0.0844    0.522  ...
# 20572          0.000290    0.0619    0.770  ...
# 24300          0.000000    0.0761    0.752  ...
# 14108          0.000001    0.0995    0.960  ...
# 6865           0.000000    0.3190    0.742  ...
#
#        month_track_album_release_date  genre_edm  genre_rap  genre_pop  \
# 12529                               1          0          0          0
# 20572                               1          0          0          0
# 24300                               1          0          0          0
# 14108                               1          0          0          0
# 6865                                1          0          1          0
#
#        genre_r&b  genre_latin  genre_rock  release_date_category  \
# 12529          0            0           1                      0
# 20572          0            1           0                      1
# 24300          1            0           0                      0
# 14108          0            0           1                      0
# 6865           0            0           0                      1
#
#        top_50_words_in_song  Top 50 words in artist
# 12529                     0                       1
# 20572                     0                       0
# 24300                     1                       0
# 14108                     1                       1
# 6865                      0                       0
#
# [5 rows x 22 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import StandardScaler
import xgboost as xgb

# Assuming df is your dataset (make sure it's already loaded)
# Split the dataset into features (X) and target (y)
X = df.drop(columns=['track_id', 'track_popularity'], errors='ignore')
y = df['track_popularity']

# One-hot encode categorical columns (if any)
X = pd.get_dummies(X, drop_first=True)

# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Define the models (including all requested models)
models = {
    "Linear Regression": LinearRegression(),
    "SVR (Support Vector Regressor)": SVR(),
    "Random Forest Regressor": RandomForestRegressor(random_state=42),
    "AdaBoost Regressor": AdaBoostRegressor(random_state=42),
    "Gradient Boosting Regressor": GradientBoostingRegressor(random_state=42),
    "XGBoost Regressor": xgb.XGBRegressor(random_state=42)
}

# Initialize a dictionary to store the results
results = {}

# Loop through the models, train, and evaluate them
for model_name, model in models.items():
    model.fit(X_train, y_train)  # Fit the model to the training data
    y_pred = model.predict(X_test)  # Predict on the test set
    
    # Calculate performance metrics
    mse = mean_squared_error(y_test, y_pred)  # Mean Squared Error
    rmse = np.sqrt(mse)  # Root Mean Squared Error
    mae = mean_absolute_error(y_test, y_pred)  # Mean Absolute Error
    r2 = r2_score(y_test, y_pred)  # R-squared (goodness of fit)
    
    # Store the results in the dictionary
    results[model_name] = {
        'MSE': mse,
        'RMSE': rmse,
        'MAE': mae,
        'R2': r2
    }

# Convert the results into a DataFrame for better readability
results_df = pd.DataFrame(results).T

# Print the results
print(results_df)
# Out:
#                                        MSE       RMSE        MAE        R2
# Linear Regression               564.092041  23.750622  20.360099  0.054150
# SVR (Support Vector Regressor)  578.806453  24.058397  20.339332  0.029478
# Random Forest Regressor         607.877963  24.655181  21.184381 -0.019268
# AdaBoost Regressor              595.421244  24.401255  21.318150  0.001619
# Gradient Boosting Regressor     593.908898  24.370246  20.797933  0.004154
# XGBoost Regressor               712.216113  26.687377  22.382456 -0.194219
